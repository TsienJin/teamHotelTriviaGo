# %% [markdown]
# Credits:
# - https://www.youtube.com/watch?v=N6Su4Hk8_-g (PyPDF2)
# - https://www.youtube.com/watch?v=MjY7UUSAqqE&t=298s (pdfplumber)

# %%
import PyPDF2 # For numPages
import pdfplumber
from datetime import date
import requests
import re

# %%
file = open("../../sampleFinancialStatements/sample1.pdf", "rb")
pdf = pdfplumber.open(file)
reader = PyPDF2.PdfFileReader(file)

# %%
import tabula
import pandas as pd

#declare the path of your file
file_path = "../../sampleFinancialStatements/sample1.pdf"

#Convert your file
df = tabula.read_pdf(file_path, pages="all")
display(df)
# Out:
# [                    Unnamed: 0  Note          31        31.1       31.2  \
#  0                          NaN   NaN    December    December   December
#  1                          NaN   NaN        2014        2013       2014
#  2                          NaN   NaN       $’000       $’000      $’000
#  3                Share capital   3.0   1,016,112     906,409  1,016,112
#  4                     Reserves   4.0   6,374,270   5,508,975  4,193,452
#  5     Share capital & reserves   NaN   7,390,382   6,415,384  5,209,564
#  6    Non-controlling interests   NaN   3,800,674   2,866,384          -
#  7             Capital employed   NaN  11,191,056   9,281,768  5,209,564
#  8              Represented by:   NaN         NaN         NaN        NaN
#  9                 Fixed assets   5.0   2,715,517   2,243,150      4,080
#  10       Investment properties   6.0   4,610,107   3,207,539          -
#  11                Subsidiaries   7.0           -           -  3,928,160
#  12        Associated companies   8.0   4,232,047   3,586,904          -
#  13                 Investments   9.0     310,759     299,896          -
#  14            Long term assets  10.0     267,060      28,646        339
#  15                 Intangibles  11.0      98,573     107,676          -
#  16                         NaN   NaN  12,234,063   9,473,811  3,932,579
#  17              Current assets   NaN         NaN         NaN        NaN
#  18   Stocks & work-in-progress   NaN         NaN         NaN        NaN
#  19        in excess of related  12.0   6,218,945   3,940,126          -
#  20                    billings   NaN         NaN         NaN        NaN
#  21           Amounts due from:   NaN         NaN         NaN        NaN
#  22              - subsidiaries  13.0           -           -  2,204,813
#  23      - associated companies  13.0     403,775     305,162      1,483
#  24                     Debtors  14.0   2,027,933   1,958,993     78,164
#  25      Short term investments  15.0     577,400     536,872          -
#  26   Bank balances, deposits &  16.0   3,020,454   4,245,990      1,621
#  27                        cash   NaN         NaN         NaN        NaN
#  28                         NaN   NaN  12,248,507  10,987,143  2,286,081
#  29         Current liabilities   NaN         NaN         NaN        NaN
#  30                   Creditors  17.0   5,323,267   4,342,963    234,396
#  31        Billings on work-in-   NaN         NaN         NaN        NaN
#  32                    progress  12.0   1,863,881   1,638,193          -
#  33  in excess of related costs   NaN         NaN         NaN        NaN
#  34                  Provisions  18.0      77,674      83,586          -
#  35             Amounts due to:   NaN         NaN         NaN        NaN
#  36              - subsidiaries  13.0           -           -    229,852
#  37      - associated companies  13.0      63,918     180,609          -
#  38                  Term loans  19.0     808,475     391,764     17,668
#  39                    Taxation  27.0     478,911     455,079     22,244
#  40             Bank overdrafts  20.0           -         736          -
#  41                         NaN   NaN   8,616,126   7,092,930    504,160
#  42          Net current assets   NaN   3,632,381   3,894,213  1,781,921
#  43     Non-current liabilities   NaN         NaN         NaN        NaN
#  44                  Term loans  19.0   4,068,696   3,675,968    500,000
#
#           31.3
#  0    December
#  1        2013
#  2       $’000
#  3     906,409
#  4   3,783,517
#  5   4,689,926
#  6           -
#  7   4,689,926
#  8         NaN
#  9       5,120
#  10          -
#  11  3,580,409
#  12         55
#  13          -
#  14        360
#  15          -
#  16  3,585,944
#  17        NaN
#  18        NaN
#  19          -
#  20        NaN
#  21        NaN
#  22  1,732,273
#  23      2,575
#  24     82,416
#  25          -
#  26    207,073
#  27        NaN
#  28  2,024,337
#  29        NaN
#  30    138,435
#  31        NaN
#  32          -
#  33        NaN
#  34          -
#  35        NaN
#  36    241,792
#  37          -
#  38      9,047
#  39     26,147
#  40          -
#  41    415,421
#  42  1,608,916
#  43        NaN
#  44    500,000  ,
#                                             Unnamed: 0       2014       2013
#  0                                                 NaN      $’000      $’000
#  1                                 Profit for the year  2,672,196  1,990,158
#  2                           Available-for-sale assets        NaN        NaN
#  3        - Fair value changes arising during the year  (146,669)    130,996
#  4   - Realised & transferred to profit and loss ac...   (18,906)      1,663
#  5                                    Cash flow hedges        NaN        NaN
#  6   - Fair value changes arising during the year, ...  (116,932)    (1,247)
#  7   - Realised & transferred to profit and loss ac...     10,725   (47,508)
#  8                        Foreign exchange translation        NaN        NaN
#  9       - Exchange difference arising during the year     15,617  (100,559)
#  10  - Realised & transferred to profit and loss ac...    (4,077)     10,013
#  11      Share of other comprehensive (expense)/income        NaN        NaN
#  12                            of associated companies   (13,880)      3,133
#  13       Other comprehensive (expense)/income for the        NaN        NaN
#  14                                              year,  (274,122)    (3,509)
#  15                                         net of tax        NaN        NaN
#  16            Total comprehensive income for the year  2,398,074  1,986,649
#  17                                   Attributable to:        NaN        NaN
#  18                        Shareholders of the Company  1,570,211  1,547,122
#  19                          Non-controlling interests    827,863    439,527
#  20                                                NaN  2,398,074  1,986,649,
#                                             Unnamed: 0         2014       2013
#  0                                                 NaN        $’000      $’000
#  1                                OPERATING ACTIVITIES          NaN        NaN
#  2                                    Operating profit    1,897,307  1,556,311
#  3                                        Adjustments:          NaN        NaN
#  4                       Depreciation and amortisation      208,571    188,633
#  5                        Share-based payment expenses       51,274     38,437
#  6   Profit on sale of fixed assets and investment ...     (26,959)    (4,949)
#  7                                Impairment of assets            -     10,715
#  8   Operational cash flow before changes in workin...    2,130,193  1,789,147
#  9                            Working capital changes:          NaN        NaN
#  10                          Stocks & work-in-progress  (1,856,459)  (594,375)
#  11                                            Debtors    (314,907)  (292,304)
#  12                                          Creditors      563,681   (65,033)
#  13                                        Investments    (217,518)   (71,646)
#  14                                        Intangibles     (10,199)    (5,256)
#  15                   Advances to associated companies    (223,772)        928
#  16                Translation of foreign subsidiaries        9,414   (73,660)
#  17                                                NaN       80,433    687,801
#  18                                  Interest received      119,032    112,888
#  19                                      Interest paid     (98,118)   (57,223)
#  20         Income taxes paid, net of refunds received    (343,424)  (293,226)
#  21       Net cash (used in)/from operating activities    (242,077)    450,240
#  22                               INVESTING ACTIVITIES          NaN        NaN
#  23             Acquisition of subsidiary and business            -   (49,184)
#  24    Advance payment for acquisition of a subsidiary    (207,930)          -
#  25  Acquisition and further investment in associat...    (477,340)  (343,788)
#  26  Acquisition of fixed assets and investment pro...    (875,773)  (873,073)
#  27  Proceeds from disposal of interest in a subsid...            -     16,281
#  28                           Disposal of subsidiaries        (153)          -
#  29  Return of capital and disposal of associated c...       53,970    303,165
#  30  Proceeds from disposal of fixed assets and inv...       73,936     58,430
#  31  Dividend received from investments and associa...      175,516    245,119
#  32              Net cash used in investing activities  (1,257,774)  (643,050)
#  33                               FINANCING ACTIVITIES          NaN        NaN
#  34                         Proceeds from share issues       99,281     73,501
#  35  Proceeds from non-controlling shareholders of ...      245,275      5,091
#  36  Proceeds from disposal of interest in a subsid...       24,991          -
#  37                           Proceeds from term loans    1,231,567  3,221,224
#  38                            Repayment of term loans    (422,128)  (921,644)
#  39   Acquisition of additional shares in subsidiaries     (22,211)  (117,464)
#  40       Dividend paid to shareholders of the Company    (723,857)  (627,183)
#  41  Dividend paid to non-controlling shareholders ...    (157,867)  (129,580)
#  42                 Net cash from financing activities      275,051  1,503,945
#  43  Net (decrease)/increase in cash and cash equiv...  (1,224,800)  1,311,135
#  44          Cash and cash equivalents as at 1 January    4,245,254  2,934,119
#  45        Cash and cash equivalents as at 31 December    3,020,454  4,245,254,
#                   Unnamed: 0   Freehold  Leasehold Unnamed: 1  Machinery  \
#  0                       NaN     Land &     Land &      Motor          &
#  1                       NaN  Buildings  Buildings   Vehicles  Equipment
#  2                       NaN      $’000      $’000      $’000      $’000
#  3                     Group        NaN        NaN        NaN        NaN
#  4                      2014        NaN        NaN        NaN        NaN
#  5                      Cost        NaN        NaN        NaN        NaN
#  6              At 1 January    121,558  1,353,706    320,642  1,991,375
#  7                 Additions      8,507     22,854      5,163     45,193
#  8                 Disposals    (1,225)   (10,124)   (30,127)   (34,908)
#  9                 Write-off          -          -    (1,202)    (1,005)
#  10      Subsidiary disposed          -       (67)          -    (1,463)
#  11         Reclassification        NaN        NaN        NaN        NaN
#  12                 - Stocks          -     13,559          -          -
#  13  - Investment properties          -     24,500          -     64,500
#  14           - Other assets          9         76   (12,276)    (2,460)
#  15     - Other fixed assets        NaN        NaN        NaN        NaN
#  16               categories   (26,645)     47,559    132,019     60,882
#  17     Exchange differences        338    (5,279)    (1,975)    (3,964)
#  18           At 31 December    102,542  1,446,784    412,244  2,118,150
#  19              Accumulated        NaN        NaN        NaN        NaN
#  20           Depreciation &        NaN        NaN        NaN        NaN
#  21        Impairment Losses        NaN        NaN        NaN        NaN
#  22             At 1 January     33,757    572,107    141,732  1,052,933
#  23      Depreciation charge      3,616     52,052     24,472    121,855
#  24          Impairment loss        NaN        NaN        NaN        NaN
#  25                (Note 26)        891     16,900          -          -
#  26                Disposals      (636)    (4,147)    (9,229)   (32,313)
#  27                Write-off          -          -    (1,023)      (782)
#  28      Subsidiary disposed          -       (66)          -    (1,206)
#  29         Reclassification        NaN        NaN        NaN        NaN
#  30                 - Stocks          -          -          -        248
#  31           - Other assets         25         67    (4,166)    (2,031)
#  32     - Other fixed assets        NaN        NaN        NaN        NaN
#  33               categories          -        260          -      (260)
#  34     Exchange differences      (117)    (2,816)      (762)    (2,418)
#  35           At 31 December     37,536    634,357    151,024  1,136,026
#  36           Net Book Value     65,006    812,427    261,220    982,124
#
#        Capital Unnamed: 2
#  0    Work-in-        NaN
#  1    Progress      Total
#  2       $’000      $’000
#  3         NaN        NaN
#  4         NaN        NaN
#  5         NaN        NaN
#  6     256,398  4,043,679
#  7     553,566    635,283
#  8           -   (76,384)
#  9         (5)    (2,212)
#  10          -    (1,530)
#  11        NaN        NaN
#  12          -     13,559
#  13          -     89,000
#  14      (698)   (15,349)
#  15        NaN        NaN
#  16  (213,815)          -
#  17      (706)   (11,586)
#  18    594,740  4,674,460
#  19        NaN        NaN
#  20        NaN        NaN
#  21        NaN        NaN
#  22          -  1,800,529
#  23          -    201,995
#  24        NaN        NaN
#  25          -     17,791
#  26          -   (46,325)
#  27          -    (1,805)
#  28          -    (1,272)
#  29        NaN        NaN
#  30          -        248
#  31          -    (6,105)
#  32        NaN        NaN
#  33          -          -
#  34          -    (6,113)
#  35          -  1,958,943
#  36    594,740  2,715,517  ,
#                   Unnamed: 0   Freehold  Leasehold Unnamed: 1  Machinery  \
#  0                       NaN     Land &     Land &      Motor          &
#  1                       NaN  Buildings  Buildings   Vehicles  Equipment
#  2                       NaN      $’000      $’000      $’000      $’000
#  3                     Group        NaN        NaN        NaN        NaN
#  4                      2013        NaN        NaN        NaN        NaN
#  5                      Cost        NaN        NaN        NaN        NaN
#  6              At 1 January     54,337  1,333,783    233,049  1,855,079
#  7                 Additions        147     30,454     48,017     52,817
#  8                 Disposals          -    (2,573)   (22,797)   (20,062)
#  9                 Write-off       (22)       (68)          -    (4,751)
#  10      Subsidiary acquired     68,377      3,762     44,033     60,517
#  11    Subsidiaries disposed          -          -          -    (1,239)
#  12         Reclassification        NaN        NaN        NaN        NaN
#  13                 - Stocks          -          -          -      (946)
#  14  - Investment properties      (676)          -          -        162
#  15           - Other assets       (92)    (7,615)          -       (30)
#  16     - Other fixed assets        NaN        NaN        NaN        NaN
#  17               categories        606     16,100     21,247     71,480
#  18     Exchange differences    (1,119)   (20,137)    (2,907)   (21,652)
#  19           At 31 December    121,558  1,353,706    320,642  1,991,375
#  20              Accumulated        NaN        NaN        NaN        NaN
#  21           Depreciation &        NaN        NaN        NaN        NaN
#  22        Impairment Losses        NaN        NaN        NaN        NaN
#  23             At 1 January     18,852    522,729    125,689    930,038
#  24      Depreciation charge      2,319     48,382     22,760    113,254
#  25          Impairment loss        NaN        NaN        NaN        NaN
#  26                (Note 26)          -     10,319          -     17,453
#  27                Disposals          -    (1,742)   (11,532)   (16,839)
#  28                Write-off       (22)      (470)    (3,913)    (3,634)
#  29      Subsidiary acquired     13,254      2,539     10,522     26,838
#  30    Subsidiaries disposed          -          -          -      (232)
#  31         Reclassification        NaN        NaN        NaN        NaN
#  32                 - Stocks          -          -          -        178
#  33           - Other assets       (26)    (1,158)          -       (89)
#  34     - Other fixed assets        NaN        NaN        NaN        NaN
#  35               categories          -        450          -      (450)
#  36     Exchange differences      (620)    (8,942)    (1,794)   (13,584)
#  37           At 31 December     33,757    572,107    141,732  1,052,933
#  38           Net Book Value     87,801    781,599    178,910    938,442
#
#        Capital Unnamed: 2
#  0    Work-in-        NaN
#  1    Progress      Total
#  2       $’000      $’000
#  3         NaN        NaN
#  4         NaN        NaN
#  5         NaN        NaN
#  6     278,232  3,754,480
#  7      99,405    230,840
#  8           -   (45,432)
#  9     (7,442)   (12,283)
#  10          -    176,689
#  11          -    (1,239)
#  12        NaN        NaN
#  13          -      (946)
#  14          -      (514)
#  15      (945)    (8,682)
#  16        NaN        NaN
#  17  (109,433)          -
#  18    (3,419)   (49,234)
#  19    256,398  4,043,679
#  20        NaN        NaN
#  21        NaN        NaN
#  22        NaN        NaN
#  23          -  1,597,308
#  24          -    186,715
#  25        NaN        NaN
#  26          -     27,772
#  27          -   (30,113)
#  28          -    (8,039)
#  29          -     53,153
#  30          -      (232)
#  31        NaN        NaN
#  32          -        178
#  33          -    (1,273)
#  34        NaN        NaN
#  35          -          -
#  36          -   (24,940)
#  37          -  1,800,529
#  38    256,398  2,243,150  ,
#                              Unnamed: 0       2014       2013  2014.1  2013.1
#  0                                  NaN      $’000      $’000   $’000   $’000
#  1                        Trade debtors  1,249,437  1,053,217       -       -
#  2         Provision for doubtful debts   (39,367)   (39,156)       -       -
#  3                                  NaN  1,210,070  1,014,061       -       -
#  4            Long term receivables due        NaN        NaN     NaN     NaN
#  5            within one year (Note 10)     11,315      1,431     195     200
#  6                       Sundry debtors     83,154     62,598     853     371
#  7   Prepaid project cost & prepayments     85,628     57,275     210     197
#  8                 Derivative financial        NaN        NaN     NaN     NaN
#  9                instruments (Note 33)     96,736    106,488  76,541  81,228
#  10                     Tax recoverable     21,652     23,189       -       -
#  11     Goods & Services Tax receivable     92,094     88,466       -       -
#  12                 Interest receivable     14,701     19,751      31      42
#  13                       Deposits paid     19,479     18,246     334     378
#  14                Land tender deposits     38,020    140,021       -       -
#  15               Advance land payments    115,493    241,796       -       -
#  16                Recoverable accounts     42,057     41,765       -       -
#  17                 Accrued receivables     17,981      9,459       -       -
#  18          Advances to subcontractors    103,294    116,386       -       -
#  19   Advances to corporations in which        NaN        NaN     NaN     NaN
#  20  the Group has investment interests        249        250       -       -
#  21         Advances to non-controlling        NaN        NaN     NaN     NaN
#  22        shareholders of subsidiaries    104,474     44,759       -       -
#  23                                 NaN    846,327    971,880  78,164  82,416
#  24        Provision for doubtful debts   (28,464)   (26,948)       -       -
#  25                                 NaN    817,863    944,932  78,164  82,416
#  26                               Total  2,027,933  1,958,993  78,164  82,416,
#                        Unnamed: 0       2014       2013   2014.1   2013.1
#  0                            NaN      $’000      $’000    $’000    $’000
#  1                Trade creditors    850,953    682,357        -       38
#  2            Customers' advances        NaN        NaN      NaN      NaN
#  3                   and deposits     98,334     74,999       57       57
#  4           Derivative financial        NaN        NaN      NaN      NaN
#  5          instruments (Note 33)    141,422     51,720   90,665   26,950
#  6               Sundry creditors  1,000,570    754,078    3,404   16,905
#  7     Accrued operating expenses  2,720,461  2,305,512  136,798   90,980
#  8                  Advances from        NaN        NaN      NaN      NaN
#  9   non-controlling shareholders    361,795    337,410        -        -
#  10              Retention monies    132,489    119,756        -        -
#  11             Interest payables     17,243     17,131    3,472    3,505
#  12                           NaN  5,323,267  4,342,963  234,396  138,435]

# %% [markdown]
# ### Function to calculate the change in percentage %

# %%
# Return the change in percentage %

def calculateChange(oldVal, newVal):
    return (newVal - oldVal) / oldVal * 100

# %% [markdown]
# ### Function to convert a string with brackets and commas to a float

# %%
# Return float

def becomeNumber(string):
    thingsToReplace = [',', '(', ')', ' ']
    
    for i in thingsToReplace:
        string = string.replace(i, '')
        
    try:
        return float(string)
    
    except:
        return 0

# %% [markdown]
# Idea is to:
#
# - Convert the pdf page into string for further processing
# - From the string, we identify the keywords
# - Get the values associated with the keywords (mindful of the years, whether the new comes first or the old)
# - Calculate the change and %
# - Come out with the MD&A Draft text
#
# - Following example is assuming oldVal is the most right value, and the newVal is the one left of it, possible like page 9 of sample1.pdf, where there are 4 values instead
#     - Likewise for the year detection in the heading

# %% [markdown]
# ## Still need to do (ordered from highest relevance, aka should tackle first):
# ### To do after getting sample documents
# - Able to get the 'units' of the money in the financial statements (is it in millions?)
#     - In the sample1.pdf case, it would be '000 for staff costs
# - To be able to get out all the rows available by checking whether got valid value anot
#     - Need to be able to filter out those introduction pages as well
#
# ### Minor improvements with more work
#
# - Currently if the rowName have special characters like '(', the rowName result might get a little wonky
#     - Can try with keyWord "asset" and the results will have some error
# - See whether can detect the 'DAY' in the headings anot, so far only got months and years
# - Try to incorporate OneAI API
# - Try for the different format as well
# - Get the reasons of the change
# - If for example is transportation expenses, do we need to auto find expenses such as "bus", "grab", etc?
# - Able to decide the time period based on the heading
#     - To see which values come first
#     - And also the criteria of "three period-to-period comparisons"
#     - ~~If the headings are in different pages, then it wouldn't work~~
#         - ~~Search the page before for the headings~~
#
# ### Things to do:
# - See whether can detect the currency anot
# - Currently, it also includes invalid results (from a different format not supported yet, but still manage to chew up some numbers idk why), so need to try to find a way to know they are invalid results and reject
#
# ### Done:
# - ~~Solve the date issues at printing statements~~
#     - ~~Need to limit the searches for date heading to first 100 words only~~
# - ~~If mulitple rows starts with the same keyWord, then it would be wrong~~
# - ~~Include the increase/decrease in sum as well in the % change~~
# - ~~Get usrKeyword in csv form and separate them~~

# %%
usrKeyword = input("(Optional) Keywords seperated by commas ").lower()
usrKeyword = usrKeyword.split(',')
for i in range(len(usrKeyword)):
    usrKeyword[i] = usrKeyword[i].strip()
# Out:
# (Optional) Keywords seperated by commas assets

# %%
specialCharacters = ['`', '~', '!', '@', '#', '$', '%', '^', '&', '*', '(',')', '+', '[', ']', '{', '}', '\\', ':', ';', "'", '"', '|', ',', '<', '.', '>', '/', '?']
allRowNames = []
# To get all the possible names of the expenses from each row
for x in range(reader.numPages):
    pageData = pdf.pages[x]
    text = pageData.extract_text().lower()
    for row in text.split('\n'):
        # To get the full row name that starts with keyWord
        rowName = ""
        for i in row:
            if (i.isdigit() or i in specialCharacters):
                break
            else:
                rowName += i
        rowName = rowName.strip()
        print(rowName)
        allRowNames.append(rowName)
        
for i in range(0, len(allRowNames)):
    try:
        allRowNames.remove('')
    except:
        continue
# Out:
# consolidated financial statements of
# samsung electronics co
# index to financial statements
# page
# independent auditors’ report
# consolidated financial statements
# consolidated statements of financial position
# consolidated statements of profit or loss
# consolidated statements of comprehensive income
# consolidated statements of changes in equity
# consolidated statements of cash flows
# notes to the consolidated financial statements
# deloitte anjin llc
#
#
# youngdeungpo-gu
#
# tel
# fax
# www
# independent auditors’ report
#
#
# to the shareholders and the board of directors of samsung electronics co
# audit opinion
# we have audited the consolidated financial statements of samsung electronics co
# subsidiaries
# december
# comprehensive income
# of cash flows
# summary of significant accounting policies
# in our opinion
# respects
# and its cash flows for the year then ended in accordance with korean international financial reporting
# standards
# basis for audit opinion
# we  conducted  our audit in  accordance  with the  korean  standards  on auditing
# responsibilities under those standards are further described in the auditor’s responsibilities for the
# audit of the consolidated financial statements section of our report
# company in accordance with the ethical requirements that are relevant to our audit of the consolidated
# financial statements in the republic of korea
# accordance with these requirements
# and appropriate to provide a basis for our audit opinion
# key audit matters
# the key audit matters are those matters that
# our audit of the consolidated financial statements of the current period
# in the context of our audit of the consolidated financial statements as a whole
# opinion thereon
#
# reasons why the matter was determined to be a key audit matter
# the information technology
# divisions perform sales promotion activities
# or implicit agreements with customers
# in notes
# activities are recognized as deductions from revenue at the expected payment amount
# as for the appropriateness of the revenue deduction amounts
# management estimates and judgments
# the consolidated financial statements
# promotion activities as a key audit matter
# how the key audit matter was addressed in the audit
# our audit procedures with respect to the company’s sales promotion activities related to the sales of
# products are as follows
# • obtained an understanding of management’s accounting policies
# controls related to the sales deduction
# • obtained an understanding and evaluated the company’s system related to the sales deduction
# • evaluated the company’s internal controls relating to the approval process of the sales
# deduction policy
# • evaluated the company’s internal controls relating to the approval process of the sales
# deduction estimation and post-settled amounts
# • verified the estimates by inspecting supporting documentation relating to the sales deduction
# transactions
# • examined the sales deduction amount by comparing the sales deduction estimates to post-
# settled amounts and inspecting supporting documentation
# -
#
# reasons why the matter was determined to be a key audit matter
# as of december
# of the harman business division
# financial assets
# for the impairment by comparing the carrying amounts of cash-generating units
# generating units
# groups have been determined based on value-in-use calculations
# the estimated future cash flows
# calculations may involve significant management estimates and judgments
# growth rates
# consolidated financial statements
# intangible assets with indefinite useful lives as a key audit matter
# how the key audit matter was addressed in the audit
# our audit procedures performed on the impairment of goodwill and intangible assets with indefinite
# useful lives of the harman business division are as follows
# • examined the objectivity and competency of the external experts used by management
# • obtained an understanding of management’s accounting policies
# controls related to the impairment of goodwill and intangible assets with indefinite useful lives
# • verified management’s determination of cash generating unit and the appropriateness of net
# assets allocated to each cash-generating unit
# • examined external data and performed a retrospective review to verify the estimates used in
# the business plans
# • verified the validity of discount rates
#
# specialists
# • verified recoverable amounts by examining the accuracy of calculation of valuation amount
# and using a sensitivity analysis
# other matters
# the consolidated financial statements of the company as of and for the year ended december
# were audited by samil pwc
# expressed an unmodified opinion on those consolidated financial statements
# -
# responsibilities of management and those charged with governance for the consolidated
# financial statements
# management is responsible for the preparation of the accompanying consolidated financial statements
# in accordance with k-ifrs
# preparation of consolidated financial statements that are free from material misstatement
# to fraud or error
# in preparing the consolidated financial statements
# assessing the company’s ability to continue as a going concern
# related to going concern and using the going concern basis of accounting unless management either
# intends to liquidate the company or to cease operations
# those charged with governance are responsible for overseeing the company’s financial reporting
# process
# auditor’s responsibilities for the audit of the consolidated financial statements
# our objectives are to obtain reasonable assurance about whether the consolidated financial statements
# as a whole are free from material misstatement
# report that includes our opinion
# that an audit conducted in accordance with ksas will always detect a material misstatement when it
# exists
# aggregate
# basis of these consolidated financial statements
# as part of an audit in accordance with ksas
# professional skepticism throughout the audit
# • identify and assess the risks of material misstatement of the consolidated financial statements
# whether due to fraud or error
# and obtain audit evidence that is sufficient and appropriate to provide a basis for our audit
# opinion
# for one resulting from error
# misrepresentations
# • obtain an understanding of internal control relevant to the audit in order to design audit
# procedures that are appropriate in the circumstances
# opinion on the effectiveness of the company’s internal control
# • evaluate the appropriateness of accounting policies used and the reasonableness of accounting
# estimates and related disclosures made by management
# • conclude on the appropriateness of the management’s use of the going concern basis of
# accounting and
# related to events or conditions that may cast significant doubt on the company’s ability to
# continue as a going concern
# to draw attention in our auditor’s report to the related disclosures in the consolidated financial
# statements or
# based on the audit evidence obtained up to the date of our auditor’s report
# events or conditions may cause the company to cease to continue as a going concern
# -
# • evaluate  the  overall  presentation
# statements
# represent the underlying transactions and events in a manner that achieves fair presentation
# • obtain sufficient appropriate audit evidence regarding the financial information of the entities
# or business activities within the company to express an opinion on the consolidated financial
# statements
# audit
# we communicate with those charged with governance regarding
# scope and timing of the audit and significant audit findings
# internal control that we identify during our audit
# we also provide those charged with governance with a statement that we have complied with relevant
# ethical requirements regarding independence
# matters that may reasonably be thought to bear on our independence
# safeguards
# from the matters communicated with those charged with governance
# were of most significance in the audit of the consolidated financial statements of the current period and
# are therefore the key audit matters
# regulation precludes public disclosure about the matter or when
# determine that a matter should not be communicated in our report because the adverse consequences of
# doing so would reasonably be expected to outweigh the public interest benefits of such communication
# the engagement partner on the audit resulting in this independent auditor’s report is byung moon yoo
# seoul
# february
# notice to readers
# this report is effective as of february
# or circumstances may have occurred between the auditors’ report date and the time the auditors’
# report is read
# may result in modifications to the auditors’ report
# -
# samsung electronics co
# consolidated statements of financial position
#
#
#
# krw krw usd usd
# assets
# current assets
# cash and cash equivalents
# short-term financial instruments
# short-term financial assets at amortized cost
# short-term financial assets at fair value
# through profit or loss
# trade receivables
# non-trade receivables
# prepaid expenses
# inventories
# other current assets
# assets held-for-sale
#
# non-current assets
# financial assets at fair value
# through other comprehensive income
# financial assets at fair value
# throughprofit or loss
# investment in associates and joint ventures
# property
# intangible assets
# net defined benefit assets
# deferred income tax assets
# other non-current assets
#
# total assets
# the above consolidatedstatementsof financial positionshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of financial position
#
#
#
# krw krw usd usd
# liabilities and equity
# current liabilities
# trade payables
# short-term borrowings
# other payables
# advances received
# withholdings
# accrued expenses
# current incometax liabilities
# current portion of long-term liabilities
# provisions
# other current liabilities
# liabilities held-for-sale
#
# non-current liabilities
# debentures
# long-term borrowings
# long-term other payables
# net defined benefit liabilities
# deferred income tax liabilities
# long-term provisions
# other non-current liabilities
#
# total liabilities
# the above consolidatedstatementsof financial positionshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of financial position
#
#
#
# krw krw usd usd
# equity attributable to owners of the company
# preference shares
# ordinary shares
# share premium
# retained earnings
# other components of equity
# accumulated  other  comprehensive  income
# attributableto assets held-for-sale
#
# non-controlling interests
# total equity
# total liabilities and equity
# the above consolidatedstatementsof financial positionshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of profit or loss
#
#
#
# krw krw usd usd
# revenue
# cost of sales
# gross profit
# selling and administrative expenses
# operating profit
# other non-operating income
# other non-operating expense
# share of net profit of associates and joint ventures
# financial income
# financial expense
# profit before income tax
# income tax expense
# profit for the year
# profit attributable to
# owners of the company
# non-controlling interests
# earnings per share
#
#
# -basic
# -diluted
# the above consolidatedstatementsofprofit or lossshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of comprehensive income
#
#
#
# krw krw usd usd
# profit for the year
# other comprehensive income
# items that will not be reclassified subsequently to
# profit or loss
# gain on valuation of financial assets at fair value
# through other comprehensive income
# share of other comprehensive income
# associates and joint ventures
# remeasurement of net defined benefit assets
# net of tax
# items that may be reclassified subsequently to
# profit or loss
# share of other comprehensive income
# associates and joint ventures
# gain
# net of tax
# gain
# derivatives
# other comprehensive income
#
# net of tax
# total comprehensive income for the year
# comprehensive income attributable to
# owners of the company
# non-controlling interests
# the above consolidatedstatementsofcomprehensive incomeshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of changes in equity
#
# equity
# other  attributable  non-
# preference  ordinary  share  retained
#
# shares shares premium earnings
# of equity theparent interests
# company
# balance as of january
# profit for the year - - -
# gain
# through other comprehensive income
# share of other comprehensive income
# associates and joint ventures
# gain on overseas business translation
# remeasurement of net defined benefit assets
# gain on valuation of cash flow hedge derivatives
# total comprehensive income for the year - - -
# dividends
# capital transactionsunder common control - - - -
# changes in consolidated entities - - - - - -
# others - - - -
# total transactions with owners - - -
# balance as of december
# the above consolidatedstatementsofchanges in equityshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of changes in equity
#
# equity
# other  attributable  non-
# preference  ordinary  share  retained
#
# shares shares premium earnings
# of equity theparent interests
# company
# balance as of january
# profit for the year - - -
# gain
# through other comprehensive income
# share of other comprehensive income of associates
# and joint ventures
# gain on overseas business translation
# remeasurement of net defined benefit assets
# gain on valuation of cash flow hedge derivatives
# total comprehensive income for the year - - -
# dividends
# capital transactionsunder common control - - - -
# changes in consolidated entities - - - - - -
# others - - - -
# total transactions with owners - - -
# balance as of december
# the above consolidatedstatementsofchanges in equityshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of changes in equity
#
# accumulated
# other  equity
# other  comprehensive  attributable  non-
# preference  ordinary  share  retained
#
# shares shares premium earnings
# of equity attributable to  the parent  interests
# assets held- company
# for-sale
# balance as of january
# profit for the year - - -
# gain on valuation of financial assets at fair
# value through other comprehensive
# income
# share of other comprehensive income
# of associates and joint ventures
# loss on overseas business translation
# remeasurement of net defined benefit
# assets
# loss on valuation of cash flow hedge
# derivatives
# reclassification to assetsheld-for-sale
# total comprehensive income for the year - - -
# dividends
# capital transactionsunder common control - - - -
# changes in consolidated entities - - - - - - -
# others - - - -
# total transactions with owners
# balance as of december
# the above consolidatedstatementsofchanges in equityshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of changes in equity
#
# accumulated
# other  equity
# other  comprehensive  attributable  non-
# preference  ordinary  share  retained
#
# shares shares premium earnings
# of equity attributable to  the parent  interests
# assets held- company
# for-sale
# balance as of january
# profit for the year - - -
# gain on valuation of financial assets at
# fair value through other comprehensive
# income
# share of other comprehensive income
# of associates and joint ventures
# loss on overseas business translation
# remeasurement of net defined benefit
# assets
# loss on valuation of cash flow hedge
# derivatives
# reclassification to assetsheld-for-sale
# total comprehensive income for the year - - -
# dividends
# capital transactionsunder common control - - - -
# changes in consolidated entities - - - - - - -
# others - - - -
# total transactions with owners
# balance as of december
# the above consolidatedstatementsofchanges in equityshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of cash flows
#
#
#
# krw krw usd usd
# operating activities
# profit for the year
# adjustments
# changes in assets and liabilities arising
# from operating activities
# cash generated from operations
# interest received
# interest paid
# dividends received
# income tax paid
# net cash from operating activities
# investing activities
# net increase in short-term financial instruments
# net decrease
# at amortized cost
# net decrease in short-term financial assets at fair value
# through profit or loss
# disposal of long-term financial instruments
# acquisition of long-term financial instruments
# disposal of financial assets at amortized cost
# acquisition of financial assets at amortized cost -
# disposal of financial assets at fair value
# through other comprehensive income
# acquisition of financial assets at fair value
# through other comprehensive income
# disposal of financial assets at fair value through profit or loss
# acquisition of financial assets at fair value
# through profit or loss
# disposal of investment in associates and joint ventures -
# acquisition of investment in associates and joint ventures
# disposal of property
# acquisition of property
# disposal of intangible assets
# acquisition of intangible assets
# cash outflow from business combinations
# cash inflow
# net cash used in investing activities
# the above consolidatedstatementsofcash flowsshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# consolidated statements of cash flows
#
#
#
# krw krw usd usd
# financing activities
# net increase in short-term borrowings
# increase in long-term borrowings
# repayment of debentures and long-term borrowings
# dividends paid
# net decrease
# net cash used in financing activities
# reclassification to assets held-for-sale
# effect of foreign exchange rate changes
# netincrease
# cash and cash equivalents
# beginning of the year
# end of the year
# the above consolidatedstatementsofcash flowsshould be read in conjunction with the accompanying notes
# -
# samsung electronics co
# notes to the consolidated financial statements
# as of december
# for the years ended december
#
#
# samsung electronics co
# on the korea stock exchange in
# business divisions
# solutions
# includes mobile phones
# memory
# division includes connected car systems
# the company is domiciled in the republic of korea and is located in suwon
# these consolidated financial statements have been prepared in accordance with korean international financial reporting
# standards
# subsidiaries
# accounting for its
#
# the consolidated subsidiaries as of december
# percentage of
# area subsidiaries industry
# ownership
# samsung electronics america
# samsung international
# samsung mexicana s
# samsung electronics home appliances america
# samsung research america
# samsung next llc
# samsung next fund llc
# neurologica corp
# samsung hvac america
# prismview
# america joyent
# viv labs
# dacor holdings
# dacor
# dacor canada co
# smartthings
# teleworld solutions
# tws latam b
# tws latam s
# snb technologies
# zhilabs inc
#
# -
# samsung electronics co
# notes to the consolidated financial statements
# percentage of
# area subsidiaries industry
# ownership
# samsung semiconductor
# samsung austin semiconductor llc
# samsung oak holdings
# stellus technologies
# semes america
# samsung electronics canada
# adgeartechnologies inc
# sigmast communications inc
# samsung eletronica da amazonia ltda
# samsung electronics mexico s
# samsung electronics digital appliance mexico
# samsung electronics latinoamerica
# samsung electronics latinoamerica miami
# samsung electronica colombia s
# samsung electronics argentina s
# samsung electronics chile limitada
# samsung electronics peru s
# america
# samsung electronics venezuela
# samsung electronics panama
# harman international industries
# harman becker automotive systems
# harman connected services
# harman connected services engineering corp
# harman da amazonia industria eletronica e participacoes ltda
# harman de mexico
# harman do brasil industria eletronica e participacoes ltda
# harman financial group llc management company
# harman international industries canada ltd
# harman international mexico
# harman kg holding
# harman professional
# rt sv co-invest
# beijing integrated circuit industry international fund
# china materialia new materials
#
# -
# samsung electronics co
# notes to the consolidated financial statements
# percentage of
# area subsidiaries industry
# ownership
# samsung electronics
# samsung electronics ltd
# samsung semiconductor europe limited
# samsung electronics gmbh
# samsung electronics holding gmbh
# samsung semiconductor europe gmbh
# samsung electronics france s
# samsung electronics italia s
# samsung electronics iberia
# samsung electronics portuguesa s
# samsung electronics hungarian private co
# samsungelectronics europe logistics b
# samsung electronics benelux b
# samsung electronics europe holding cooperatief u
# samsung electronics nordic aktiebolag
# samsung electronics slovakia s
# samsung display slovakia s
# samsung electronics polska
# samsung electronics poland manufacturing sp
# europe
# samsung electronics romania llc
# samsungelectronics austria gmbh
# samsung electronics switzerland gmbh
# samsung electronics czech and slovak s
# samsung electronics baltics sia
# samsung electronics greece s
# samsung electronics air conditioner europe b
# samsung nanoradiodesign center
# samsung denmark research center aps
# samsung cambridge solution centre limited
# zhilabs
# foodient ltd
# samsung electronics rus company llc
# samsung electronics rus kaluga llc
# samsung electronics ukraine company llc
# samsung electronics central eurasia llp
# samsung electronics overseas b
# samsung r
# samsung electronics caucasus co
#
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# percentage of
# area subsidiaries industry
# ownership
# akg acoustics gmbh manufacture and sale of audio products
# amx uk limited sale of audio products
# arcam limited management of overseas subsidiaries
# a
# harman audio iberia espana sociedad limitada sale of audio products
# harman automotive uk limited manufacture of audio products
# harman becker automotive systems gmbh manufacture and sale of audio products
# harman becker automotive systems italy s
# harman becker automotive systems manufacturing kft manufacture of audio products
# harman belgium sa sale of audio products
# harman connected services ab
# harman finland oy connected service provider
# harman connected services gmbh connected service provider
# harman connected services limited connected service provider
# harman connected services poland sp
# harman connected services uk ltd
# harman consumer nederland b
# harman deutschland gmbh sale of audio products
# europe
# harman france snc sale of audio products
# harman holding gmbh
# harman hungary financing ltd
# harman inc
# harman international estonia ou r
# harman international industries limited sale of audio products
# harman international romania srl r
# harman finance international
# harman international s
# harman management gmbh management of overseas subsidiaries
# harman professional kft manufacture of audio products
# martin manufacturing
# harman professional denmark aps sale of audio products
# red bend software ltd
# red bend software sas software design
# studer professional audio gmbh sale of audio products
# harman connected services ooo connected service provider
# harman rus cis llc sale of audio products
#
# -
# samsung electronics co
# notes to the consolidated financial statements
# percentage of
# area subsidiaries industry
# ownership
# samsung gulf electronics co
# samsung electronics turkey
# samsung electronics levant co
# samsung electronics maghreb arab
# samsung electronics egypt s
# samsung electronics israel ltd
# samsung electronics tunisia s
# samsung electronics pakistan
# samsung electronics saudi arabia ltd
# middle east
# samsung semiconductor israel r
#
# corephotonics ltd
# samsung electronics south africa
# samsung electronics south africa production
# samsung electronics west africa ltd
# samsung electronics east africa ltd
# global symphony technology group private ltd
# harman connected services morocco connected service provider
# harman industries holdings mauritius ltd
# red bend ltd
# samsung asia pte
# samsung electronics singapore pte
# samsung malaysia electronics
# samsung electronics display
# samsung electronics
# samsung vina electronics co
# samsung electronics vietnam co
# samsung electronics vietnam thainguyen co
# samsung electronics hcmc ce complex co
# samsung display vietnam co
# pt samsung electronics indonesia
# asia pt samsung telecommunicationsindonesia
#
# china
# samsung electronics philippines corporation
# samsung electronics australia pty
# samsung electronics new zealand limited
# samsung india electronics private ltd
# samsung display noida private limited
# samsung r
# samsung r
# samsung nepal services pvt
# samsung japan corporation
# samsung r
# samsung electronics japan co
#
# -
# samsung electronics co
# notes to the consolidated financial statements
# percentage of
# area subsidiaries industry
# ownership
# harman connected services corp
# asia harman international
#
# china
# harman singapore pte
# samsung
# samsung electronics hong kong co
# samsung electronics taiwan co
# samsung electronics huizhou co
# tianjin samsung electronics co
# suzhou samsung electronics co
# samsung suzhou electronics export co
# samsung electronics suzhou computer co
# tianjin samsung telecom technology co
# shenzhen samsung electronics telecommunication co
# beijing samsung telecom r
# samsung electronics china r
# samsung mobile r
# samsung r
# shanghai samsung semiconductor co
# samsung
# china  samsung semiconductor xianco
# samsung electronics suzhou semiconductor co
# tianjin samsung led co
# samsung semiconductor
# samsung display dongguan co
# samsung display tianjin co
# samsung suzhou module co
# samsung suzhou lcd co
# semes
# harman
# harman
# harman automotive electronic systems
# harman commercial
# harman connected services solutions
# harman holding limited sale of audio products
# harman international
# harman technology
#
# -
# samsung electronics co
# notes to the consolidated financial statements
# percentage of
# area subsidiaries industry
# ownership
# samsung display co
# su materials manufacture of display components
# steco co
# semes co
# samsung electronics service co
# samsung electronics service customer satisfaction call center for repair services for electronic devices
# samsung electronics sales co
# samsung electronics logitech co
# samsung medison co
# mirero system co
# process defect and quality control software
# dowooinssys co
# gf-system co
# harman international korea software development and supply
# samsung venture capital union
# domestic
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# samsung venture capital union
# growth type private equity trust specialized in semiconductors investment on semiconductor industry
# system lsi mutual benefit private equity trust investment on semiconductor industry
#
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# summary of financial data of major consolidated subsidiaries is as follows
#
#
# profit
# major subsidiaries
# samsung display
# samsung electronics america
# samsung electronics vietnam thainguyen co
# samsung
# harman and its subsidiaries
# samsung
# samsung electronics vietnam co
# samsung electronics europe holding cooperatief u
# samsung semiconductor
# samsung asia pte
# shanghai samsung semiconductor co
# samsung display vietnam co
# samsung austin semiconductor llc
# samsung eletronica da amazonia ltda
# samsung india electronics private ltd
# thai samsung electronics co
# samsung electronics
# samsung electronics gmbh
# samsung electronics hcmc ce complex co
# samsung electronics hungarian private co
# samsung electronics benelux b
# samsung display dongguan co
# samsung electronics europe logistics b
# samsung electronics france s
# samsung japan corporation
#
#
# -
# samsung electronics co
# notes to the consolidated financial statements
#
#
# profit
# major subsidiaries
# samsung display
# samsung electronics america
# harman and its subsidiaries
# samsung
# samsung electronics vietnam thainguyen co
# samsung
# samsung electronics vietnam co
# samsung electronics europe holding cooperatief u
# samsung semiconductor
# samsung asia pte
# samsung display vietnam co
# samsungeletronicada amazonia ltda
# samsung india electronics private ltd
# samsung austin semiconductor llc
# shanghai samsung semiconductor co
# thai samsung electronics co
# samsung electronics
# samsung electronics hcmc ce complex co
# samsung electronics gmbh
# samsung electronics hungarian private co
# samsung semiconductorxian co
# samsung electronics europe logistics b
# samsung electronics benelux b
# samsung suzhou lcd co
# samsung display dongguan co
#
#
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# changes in consolidation scope during the yearended december
# change area subsidiary description
# teleworld solutions
# tws latam b
# america acquisition
# tws latam s
# included
# snb technologies
# asia
# samsung electronics singapore pte
#
# domestic system lsi mutual benefit private equity trust
# harman connected services south america s
# america everythingdacor
# excluded distinctive appliances of california
# asia
# martin professional pte
#
# china samsung tianjin mobile development center
#
#
# the principal accounting policies used to prepare the consolidatedfinancial statements are set out below
# of the amendments to the korean ifrs and new interpretations set out below
# the consolidatedfinancial statements as of and for the year ended december
# the consolidatedfinancial statements as of and for the year ended december
# the company maintains its accounting records in korean won and prepares statutory financial statements in the korean
# language
#
# english from the korean language financial statements
# certain information attached to the korean language financial statements
# company’s financial position
# financial statements
# the consolidated financial statements of the company presented have been prepared in accordance with korean ifrs
# are the standards
#
# korean ifrspermits the use of critical accounting estimates in the preparation of the consolidated financial statements and
# requires management judgments in applying accounting policies
# complexity
# note
# -
# samsung electronics co
# notes to the consolidated financial statements
#
#
# the company applied the following amended and enacted standards for the first time for their annual reporting period
# commencing january
# amendments to korean ifrs
# to consider the integration of the required activities and assets as a business
# acquisition to include an input and a substantive process that together significantly contribute to the ability to create outputs
# and excludes economic benefits from the lower costs
# all of the fair value of gross assets acquired is concentrated in a single asset
# would not represent a business
#
# the amended accounting standard issued that is not mandatory for the annual reporting period commencing january
# and has not been early adopted by the company is as follows
# amendments to korean ifrs
# the amendments introduce a practical expedient that simplifies how a lessee accounts for covid-
# and a lessee may elect not to assess whether rent concessions occurring as a direct consequence of the covid-
# are lease modifications
# concession the same way it would account for the change applying this standard if the change were not a lease modification
# the amendment is effective for annual reporting periods beginning on or after june
# amendments to korean ifrs
# the amendments prohibit deducting from the cost of an item of property
# produced while bringing that asset to the location and condition necessary for it to be capable of operating in the manner
# intended by management
# items
# early adoption permitted
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# the companyprepares theconsolidated financial statements in accordance with korean ifrs
# statements
#
# subsidiaries are all entities
# the corresponding investee when it is exposed
# the ability to affect those returns through its power over the investee
# company obtains control of a subsidiary and ceases when the company loses control of the subsidiary
# the company applies the acquisition method to account for business combinations
# at the fair values ofthe assets transferred
# a business combination are initially measured at their fair values at the acquisition date
# controlling interest in the acquiree on an acquisition-by-acquisition basis in the event of liquidation at the non-controlling
# interest’s proportionate share of the recognized amounts of acquiree’s identifiable net assets
# expensed as incurred
# the excess of consideration transferred
# value of any previous equity interest in the acquired entity over the fair value of the net identifiable assets acquired is recorded
# as goodwill
# is recognized directly in the profit or loss as a bargain purchase
# balances of receivables and payables
# within the company are eliminated
# with the policies adopted by the company
#
# transactions with non-controlling interests that do not result in loss of control are accounted for as equitytransactions–that
# is
# and the relevant share acquired of the carrying value of net assets of the subsidiary is recorded in equity
# disposals ofnon-controlling interests are also recorded in equity
#
# if the company loses control of a subsidiary
# value at the date when control is lost and any resulting differences are recognized in profit or loss
# the initial carrying amount for the subsequent measurementof the retained interest accounted for as an associate
# or financial asset
# accounted for as if the company had directly disposed of the related assets or liabilities
# other comprehensive income are reclassified into profit or lossor equity
#
# each component of profit or loss and other comprehensive income isattributed to owners of the parent and to non-controlling
# interests
# in a negative balance ofnon-controlling interests
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# associates are all entities over which the company has significant influencebut does not have control
# which from
# equity method of accounting
# and its associates are eliminated to the extent of the company’s interest in the associates
# an associate equals or exceeds its interest in the associate
# company’s net investment in the associate
# company’s interest is reduced to zero
# the company has incurred legal or constructive obligations or made payments on behalf of the associate
# evidence of impairment for the investment in the associate
# amount of the associate and its carrying amount as an impairment loss
# those of the company for like transactions and events in similar circumstances
# make the associate’s accounting policies conform to those of the company when the associate’s financial statements are used
# by the entity in applying the equity method
#
# a joint arrangement of which two or more parties have joint control is classified as either a joint operation or a joint venture
# a joint operator has rights to the assets
# assets
# relating to the joint venture and accounts for that investment using the equity method
#
#
# items included in the consolidated financial statements of each of the company’s entities are measured using the currency of
# the primary economic environment in which each entity operates
# statements are presented in korean won
#
# foreign currency transactions are translated into the functional currency using the exchange rates prevailing at the dates ofthe
# transactions or valuation where items are re-measured
# such transactions and from the translation at year-end exchange rates of monetary assets and liabilities denominated in foreign
# currencies are recognized in profit or loss
# as equity instruments at fair value through profit or loss and equity instruments at fair value through other comprehensive
# income are recognized in profit or loss and other comprehensive income
#
# the results and financial position of all the foreign entities that have a functional currency different from the presentation
# currency of the company are translated into the presentation currency as follows
#
# the end of the reporting date
#
# this average is not a reasonable approximation of the cumulative effect of the rates prevailing on the transaction dates
# in which case income and expenses are translated at the rate on the dates of the transactions
#
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# cash and cash equivalents include cash on hand
# high liquidity that arereadily convertible to a known amount of cash and aresubject to an insignificant risk of change in value
#
#
# from january
# financial assets in the following measurement categories
# - financial assets measured at fair value
# - financial assets measured at amortized cost
# the classification depends on the company’s business model for managing the financial assets and the contractual terms of
# the cash flows
# for financial assets measured at fair value
# income
# company reclassifies debt investments only when its business model for managing those assets changes
# for investments in equity instruments that are not held for trading
# made an irrevocable election at the time of initial recognition to account for the equity investment at fair value through other
# comprehensive income
# as other comprehensive income are recognized in profit or loss
#
# at initial recognition
# fair value through profit or loss
# issuance of the financial liabilitiesare added to its fair value
# profit or loss are expensed in profit or loss
# hybrid
# flows are solely payment of principal and interest
# a
# subsequent measurement of debt instruments depends on the company’s business model for managing the asset and the cash
# flow characteristics of the asset
# categories
#
# assets that are held for collection of contractual cash flows where those cash flows represent solely payments of principaland
# interest are measured at amortized cost
# and is not part of a hedging relationship is recognized in profit or loss when the asset is derecognized or impaired
# income from these financial assets is included in ‘financial income’ using the effective interest rate method
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# assets that are held for collection of contractual cash flows and for selling the financial assets
# represent solely payments of principal and interest
# movements in the carrying amount are taken through other comprehensive income
# loss
# loss
# income is reclassified from equity to profit or loss
# using the effective interest rate method
# expenses’ and impairment losses are presented in ‘other non-operating expenses’
#
# assets that do not meet the criteria for amortized cost or fair value through other comprehensive income are measured at fair
# value through profit or loss
# loss and is not part of a hedging relationship is recognized in profit or loss and presented in the consolidated statement of
# profit or loss within ‘other non-operating income’ or ‘other non-operating expenses’ in the year in which it arises
# b
# the company subsequently measures all equity investments at fairvalue
# present  fair  value  gains  and  losses  on  equity  investments  in  other  comprehensive  income
# reclassification of fair value gains and losses to profit or loss following the derecognition of the investment
# asset is derecognized
# income recognized in equity is reclassified to retained earnings
# recognized in profit or loss as ‘other non-operating income’ when the right to receive payments is established
# changes in the fair value of financial assets at fair value through profit or loss are recognized in ‘other non-operating income’
# or ‘other non-operating expenses’ in the consolidated statementsof profit or loss as applicable
#
# the company assesses on a forward-looking basis the expected credit losses associated with its debt instruments carried at
# amortized cost and fair value through other comprehensive income
# there has been a significant increase in credit risk
# requires expected lifetime losses to be recognized from initial recognition of the receivables
#
# regular way purchases and sales of financial assets are recognized or derecognized on a trade date basis
# derecognized when the rights to receive cash flows from the financial assets have expired or have been transferred and the
# company has transferred substantially all the risks and rewards of ownership
# because the company has retained substantially all the risks and rewards of ownership of the transferred asset
# continues to recognize the transferred asset in its entirety and recognizes a financial liability for the consideration received
# the company classified the financial liability as ‘borrowings’ in the consolidated statement of financial position
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# financial assets and liabilities are offset and the net amount reported in the statements of financial position where there is a
# legally enforceableright to offset the recognized amounts and there is an intention to settle on a net basis or realize the assets
# and settle the liability simultaneously
# enforceable in the normal course of business and in the event of default
# counterparty
#
# trade receivables are amounts due from customers for inventories sold or services performed in the ordinary course of business
# if collection is expected in one year or less
# they are presented as non-current assets
# amortized cost using the effective interest method
# component
#
# inventoriesare stated at the lower of cost and net realizable value
# for materials in transit
# costs and related production overheads
# waste
# expenses
# the company regularly estimates the future customer demand in the products that may cause a significant change in the
# valuation allowance and recognizes the valuation allowance if there is any case such as excess
# market value
#
# property
# cost includes expendituresthatare directly attributable to the acquisition of the items
# asset’s carrying amount or recognized as a separate asset
# associated with the item will flow to the company and the cost of the item can be measured reliably
# those parts that are replaced is derecognized and repairs and maintenance expenses are recognized in profit or loss in the period
# they are incurred
# depreciationon tangible assets is calculated using the straight-line method to allocate the difference between their cost and
# their residual values over their estimated useful lives
# acquisition
# asset and are amortized over the estimated useful lives
# the company’s policy is that property
# estimated useful lives
# buildingsand structures
# machinery and equipment
# other
# the depreciation method
# appropriate
# -
# samsung electronics co
# notes to the consolidated financial statements
# amount if the asset’s carrying amount is greater than its estimated recoverable amount
# determined by comparing the proceeds with the carrying amount and are recognized within the consolidated statement of
# profit or loss as ‘othernon-operatingincome’ or ‘other non-operating expenses’
#
# general and specific borrowing costs that are directly attributable to the acquisition
# asset are capitalized during the period of time that is required to complete and prepare the asset for its intended use
# income earned on the temporary investment of specific borrowings pending their expenditure on qualifying assets is deducted
# from the borrowing costs eligible for capitalization
# incurred
#
# goodwill represents the excess of the cost of an acquisition over the fair value of the company’s share of the net identifiable
# assets of the acquired subsidiaries
# acquisition of subsidiaries’ businesses is included in intangible assets and goodwill on an acquisition of associates and joint
# ventures’ shares is included in the investments in associates and joint ventures
# intangible assets
# amortization and accumulated impairment losses
# internally generated development costs are the aggregate costs recognized after meeting the asset recognition criteria
# including technical feasibility
# are regarded as intangible assets with an indefinite useful life and not amortized because there is no foreseeable limit to the
# period over which the assets are expected to be utilized
# estimation of the benefits associated with the membership rights and assessment of impairment indicators
# in the market value
# amortized using the straight-line method over their estimated useful lives
# the company’s policy is that intangible assets should be amortized over the following estimated useful lives
# estimated useful lives
# development costs
# trademarks
#
# goodwill or intangible assetswithindefinite useful lives are not subject to amortization and are tested annually for impairment
# assets that are subject to amortization are reviewed for impairment whenever events or changes in circumstances indicate that
# the carrying amount may not be recoverable
# amount exceeds its recoverable amount
# value in use
# identifiable cash flows
# reviewed for possible reversal of the impairment at the end of each reporting period
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# non-current assets
# principally through a sale transaction and the sale is considered highly probable
# carrying amount and the fair value less costs to sell
# the carrying amount of relevant assets
# ‘other non-operating expenses’
#
#
# the company shall classify all financial liabilities as financial liabilities measured subsequently at amortized cost
# the following
# - financial liabilities at fair value through profit or loss
# subsequently measured at fair value
# - financial liabilities that arise when a transfer of a financial asset does not qualify for derecognition or when the continuing
# involvement approach applies
# financial assets
# - financial guarantee contracts
# higher of
#
#
# with the principles of korean ifrs
# - commitments to provide a loan at a below-market interest rate
# measure it at the higher of
#
#
# with the principles of korean ifrs
# - contingent consideration recognized by an acquirer in a business combination to which korean ifrs
# combinations applies
# recognized in profit or loss
#
# financial liabilities are removed from the consolidated statementsof financial position when it is extinguished
# when the obligation specified in the contract is discharged or cancelled or expired or when the terms of an existing financial
# liability are substantially modified
# transferred to another party and the consideration paid
# recognized in profit or loss
#
# trade payables are amounts due to suppliers for inventories purchased or services received in the ordinary course of business
# if payment is expected to be made within
# current liabilities
# cost using the effective interest method
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# borrowings are recognized initially at fair value
# any difference between cost and the redemption value is recognized in the consolidatedstatement of profit or loss over the
# period of the borrowings using the effective interest method
# period longer than
# otherwise
#
# a provision is recognized when the company has a present legal or constructive obligation as a result of a past event
# probable that an outflow of resources embodying economic benefits will be required to settle the obligation
# estimate can be made of the amount of the obligation
# provisions are measured at the present value of the expenditures expected to be required to settle the obligation using a pre-
# tax rate that reflects current market assessments of the time value of money and the risks specific to the obligation
# in the provision due topassage of time is recognized as interest expense
# the company discloses a contingent liabilityif there is a possible obligation from past events whose existence may only be
# identified by the occurrence of uncertain future events
# resources is uncertain
# estimated
#
# the company hasa variety of retirement pension plans including defined benefit and definedcontribution plans
# a defined contribution plan is a pension plan under which the company pays fixed contributions into a separate fund
# company has no legal or constructiveobligations to pay further contributions if the fund does not hold sufficient assets to pay
# allemployees the benefits relating to employee service in the current and prior periods
# company pays contributions to annuity plans that are managed either publicly or privately on a mandatory
# voluntary basis
# contributions are recognized as employee benefit expense when they are due
# to the extent that a cash refund or a reduction inthe futurepayments is available
# ...
# per share are the same for the yearsended december
# -
# samsung electronics co
# notes to the consolidated financial statements
#
#
# and liabilities arising from operating activities for the years ended december
# - adjustments
#
#
# adjustments
# income tax expense
# financial income
# financial expenses
# post-employment benefits
# depreciation
# amortization
# bad debt expenses
# dividend income
# share of profit of associates and joint ventures
# gain on disposal of property
# loss on disposal of property
# loss on valuation of inventories
# gain on disposal of investments
# others
# total
# - changes in assets and liabilities arising from operating activities
#
#
#
# changes in assets and liabilities
# decrease in trade receivables
# decrease
# increase in prepaid expenses
# decrease
# increase
# increase
# increase in advances received
# increase
# increase
# increase
# payment of post-employment benefits
# increasein plan assets
# other
# total
# -
# samsung electronics co
# notes to the consolidated financial statements
#
#
# valuation of financial assets at fair value through other comprehensive income
# valuation of investments in associates and joint ventures
# reclassification of constructioninprogress to property
# acquisition of right-of-use assets
# reclassification of current portion of debentures
# reclassification of current portion of long-term borrowings
#
#
# cash flows from  non-cash transactions as of
# as of financing  new lease  december
#
# short-term borrowings
# debentures and long-term borrowings
# total
#
#
# cash flows from  non-cash transactions
# as of financing  new lease  as of
#
# short-term borrowings
# debentures and long-term borrowings
# total
#
# policies
# for the years ended december
# w
# in relation to the lease liabilities amount to w
#
# and with short-term maturities
# december
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# the company’s financial risk management focuses on minimizing market risk
# operating activities
# closely monitors and manages such risks
# the finance team mainly carries out the company’s financial risk management
# management policies
# implements the global financial risk management policy
# the company also manages foreign exchange risk by monitoring foreign exchange rate fluctuations at local finance centers
# across major regions
# exchange transactions
# the company’s financial assets that are under financial risk management are comprised of cash and cash equivalents
# term financial instruments
# under financial risk management are comprised of trade payables
#
#
# the company is exposed to foreign exchange riskarising from its global operations performed in currencies other than its
# functional currency
# rupee
# the company focuses on minimizing the impact of foreign exchange fluctuation by maintaining the equal amount of assets
# and liabilities denominated in each foreign currency
# exchange position
# import and export
# cash-in currency to be matched up with the cash-out currency
# the foreign exchange risk to efficiently mitigate such risk
# prohibited
# as of december
# effects
# follows
# december
#
# usd
# eur
# inr
# jpy
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# risk of changes in interest rates for floating interest rate financial instruments is defined as the risk that the fair value of
# components of the statements of financial position
# instrument
# risk exposure is mainly driven by its floating interest rate debt obligations and interest-bearing deposits
# implemented policies and operates to minimize uncertainty arising from changes in interest rates and financial expenses
# as of december
# interest rates on floating interest rate financial assets and liabilities are presented below
# december
#
# financial assets
# financial liabilities
# net effect
#
# the company’s investment portfolio consists of direct and indirect investments in equity instruments classified as financial
# assets at fair value through other comprehensive income and financial assets at fair value through profit or loss
# line with the company’s strategy
# as of december
# changes in other comprehensive income
# changes in profit before tax of w
#
# credit risk arises during the normal course of transactions and investing activities where clients or other parties fail to discharge
# an obligation
# client’s and counterparty’s financial conditions
# maintained for trade receivables related to trading partners situatedin higher risk countries
# credit risk can arise from transactions with financial institutions which include financial instrument transactions such as cash
# and cash equivalents
# which have a strong international credit rating
# prior transaction history are approved
# the company generally enters into a financial agreement with no restrictions
# collateral and
# as of december
# carrying amount of its financial assets
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# due to large investments made by the company
# to achieve this goal by periodically forecasting its capital balance
# expenses
# the company manages its liquidity risk by periodically forecasting projected cash flows
# company works with the local finance center and provides liquidity support by utilizing a globally integrated finance structure
# such as cash pooling
# support from the local finance center and the company
# entities and contributes to minimizing liquidity risk and strengthening the company’s competitive position by reducing capital
# operation expenses and financial expenses
# for the need of large scale of liquidity
# guarantees
# as of december
# to their remaining contractual maturity
# december
# less than more than
#
# financial liabilities
# december
# less than more than
#
# financial liabilities
# the table above shows the company’s financial liabilities based on the remaining period at the consolidated statements of
# financial position date until the contractual maturity date
# cash flows
# the company’s derivative financial liabilities of w
# within the less than
# term
# net fair value basis rather than by maturity date
# company to manage the exchange rate profile
# derivatives that are settled on a gross basis by delivery of the underlying item
# settled within the next
# there is no maximum liquidity risk exposure from those other than the above financial liabilities
# performance guarantees
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# the company applies cash flow hedge accounting to hedge the foreign currency risk of forecasted transaction including
# hedging the price risk associated with inventory
# as of december
# december
#
# currency forward exchange contracts
# current items
# non-current items
# total
# for the years ended december
# portion of changes in fair value of derivatives that are designated and qualify as cash flow hedges in other comprehensive
# income
# recognizes the gains and losses relating to the ineffective portion in profit or loss
#
# to profit or loss amount to gain of w
# other comprehensive income to the carrying amount of inventory amount to w
#
#
# the purpose of capital management is to maintain a sound capital structure
# credit ratings and debt ratio
# the company’s capital risk management policy has not changed since the prior reporting periods
# maintained an aa-and aa
# the total liabilitiesto equity ratios as of december
#
#
# total liabilities
# total equity
# debt ratio
# -
# samsung electronics co
# notes to the consolidated financial statements
#
#
# follows
#
# december
#
# financial assets
# cash and cash equivalents
# short-term financial instruments
# short-term financial assets at amortized cost
# short-term financial assets at fair value
# through profit or loss
# trade receivables
# financial assets at fair value through
# other comprehensive income
# financial assets at fair value through
# profit or loss
# other
# total financial assets
# financial liabilities
# trade payables
# short-term borrowings
# other payables
# current portion of long-term liabilities
# debentures
# long-term borrowings
# long-term other payables
# other
# total financial liabilities
#
#
# w
# value
#
# disclosures in accordance with korean ifrs
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# december
#
# december
#
#
# financial assets at fair value through
# other comprehensive income
# financial assets at fair value through
# profit or loss
# other -
#
# debentures -
# long-term other payables - -
# other -
#
# december
#
#
# financial assets at fair value through
# other comprehensive income
# financial assets at fair value through
# profit or loss
# other -
#
# debentures -
# long-term other payables - -
# other -
# the levels of the fair value hierarchy and its application to financial assets and liabilities are described below
#
#
# directly or indirectly
#
# the fair value of financial instruments traded in active markets is based on quoted market prices at the statementsof financial
# position date
# broker
# market transactions on an arm’s length basis
# current bid price
# investments
# the fair value of financial instruments that are not traded in an active market
# determined by using valuation techniques
# it is available and rely as little as possible on entity-specific estimates
# instrument are observable
# -
# samsung electronics co
# notes to the consolidated financial statements
# if one or more of the significant inputs are not based on observable market data
# the company performs the fair value measurements required for financial reporting purposes
# and discusses valuation processes and results at least once every quarter in line with the company’s quarterly reporting
# dates
# events or changes in circumstances have occurred
# specific valuation techniques used to value financial instruments include
#
#
# financial position date
# other techniques
# instruments
# estimate of fair value
#
# the company utilizes a present value technique to discount future cash flows using a proper interest rate for corporate
# bonds
# the following table presents the valuation technique and the inputs used for major financial instruments classified as level
#
#
#
# input range
# classification fair value valuation technique level
#
# financial assets at fair value through other comprehensive income
# permanent growth rate -
# maltani
#
# cost of capital
# permanent growth rate -
# samsung venture investment
#
# cost of capital
# corning incorporated  risk-adjusted discount rate
#
# convertible preference shares price volatility
# long-term other payables
# probability-weighted
# contingent financial liability
# discounted cash flow
# -
# samsung electronics co
# notes to the consolidated financial statements
#
#
#
#
# financial assets
# balance as of january
# acquisitions
# disposals
# amount recognized in profit or loss
# amountrecognized in other comprehensive income
# other
# balance as of december
#
#
#
# financial liabilities
# balance as of january
# repayment -
# amount recognized in profit or loss
# other
# balance as of december
#
# sensitivity analysis of financial instruments is performed to measure favorable and unfavorable changes in the fair value of
# financial instruments which are affected by the unobservable parameters
# is affected by more than two input parameters
# the results of the sensitivity analysis for effect on profit or loss
# from changes in inputs for major financial instruments which are categorized within level
# analysis are as follows
#
#
# classification profit or loss equity profit or loss equity
# financial assets at fair value through
# other comprehensive income
#
# and discount rate
# -
# samsung electronics co
# notes to the consolidated financial statements
#
#
# the chief operating decision-maker has been identified as the management committee
# segments based on the units reported to the management committee
# profits of each operating segment in order to assess performance and to make strategic decisions regarding the allocation of
# resources to the segment
# sales revenue consists mostly of product sales
# internal organization and revenue streams
#
# the segment information for each reporting period isprepared after allocating intercompany reconciliations to depreciation
# amortization of intangible assets and operating profits
# the disclosure as these have not been provided regularly to the management committee
#
#
#
#
# intercompany
#
# total
# korean won
#
# total revenue
# intercompany
# revenue
# net revenue
# depreciation
# amortization
# operating profit
#
#
#
#
#
#
# intercompany
#
# total
# korean won
#
# total revenue
# intercompany
# revenue
# net revenue
# depreciation
# amortization
# operating profit
#
#
#
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# the regional segment information provided to the management committee for the reportable segments as of and for the years
# ended december
#
#
# asia intercompany
#
#
# net revenue
# non-current assets
#
#
# asia intercompany
#
#
# net revenue
# non-current assets
#
# -
# samsung electronics co
# notes to the consolidated financial statements
#
#
# sale and purchase transactions with related parties for the years ended december
#
#
# disposal of purchase of
#
# korean won
# samsung sds
# samsung electro-mechanics
# associates and samsung sdi
# joint ventures cheil worldwide
# other
# total
# samsung c
# other related
# other
# parties
# total
# samsung engineering
# s-
# other
# other
# total
#
#
#
# enterprise group in accordance with the monopoly regulation and fair trade act
#
#
#
# disposal of purchase of
#
# korean won
# samsung sds
# samsung electro-mechanics
# associates and samsung sdi
# joint ventures cheil worldwide
# other
# total
# samsung c
# other related
# other
# parties
# total
# samsung engineering
# s-
# other
# other
# total
#
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# enterprise group in accordance with the monopoly regulation and fair trade act
#
# balances of receivables and payables arising from sales and purchases of goods and services as of december
#
#
#
# december
#
# samsung sds
# samsung electro-mechanics
# associates and  samsung sdi
# joint ventures cheil worldwide
# other
# total
# samsung c
# other related parties other
# total
# samsung engineering
# s-
# other
# other
# total
#
#
#
# enterprise group in accordance with the monopoly regulation and fair trade act
#
#
# december
#
# samsung sds
# samsung electro-mechanics
# associates and  samsung sdi
# joint ventures cheil worldwide
# other
# total
# samsung c
# other related parties other
# total
# samsung engineering
# s-
# other
# other
# total
#
#
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# enterprise group in accordance with the monopoly regulation and fair trade act
#
# respectively
# ventures forthe yearended december
# ended december
# electro-mechanics co
#
# for the yearended december
# the company declared w
# accordance with korean ifrs
# fair trade act
#
# w
# amounted to w
#
# the compensation paid or payable to key management
#
#
#
#
# short-term employee benefits
# post-employment benefits
# other long-term employee benefits
# -
# samsung electronics co
# notes to the consolidated financial statements
#
#
# the profit or loss allocated to non-controlling interests and accumulated non-controlling interests of subsidiaries that are
# material to the companyfor the years ended december
# samsung display co
#
# percentage of non-controlling interests
# balance as of january
# profit for the year
# dividends
# other
# balance as of december
#
# before intercompany eliminationsfor the years december
#
# samsung display co
#
# current assets
# non-current assets
# current liabilities
# non-current liabilities
# equity attributable to
# owners of the parent company
# non-controlling interests
#
# samsung display co
#
# sales
# profit for the year
# other comprehensive income
# total comprehensive income attributable to
# owners of the parent company
# non-controlling interests
# -
# samsung electronics co
# notes to the consolidated financial statements
#
# samsung display co
#
# cash flows from operating activities
# cash flows from investing activities
# cash flows from financing activities
# reclassification to assetsheld-for-sale
# effect of exchange rate changes on cash and cash equivalents
# increase
# cash and cash equivalents at beginning of the year
# cash and cash equivalents at end of year
#
#
# for the year ended december
# ltd
# technologies co
# completed within a year
#
#
# assets held-for-sale
# cash and cash equivalents
# inventories
# other current assets
# property
# intangible assets
# other non-current assets
# total
# liabilities held-for-sale
# current liabilities
# non-current liabilities
# total
#
#
# loss on overseas business translation
# -

# %%
# found = 0     # If found = 1, means found the keyWord in PDF, if found = 0, means cannot find keyWord in PDF, need key in a new keyWord again
# unitMultiply = 0
# possibleYears = range(1900, date.today().year + 1)
# # The months are  in small letters so it's not caps-sensitive
# possibleMonths = ["december", "november", "october", "september", "august", "july", "june", "may", "april", "march", "february", "january"]
# possibleUnits = ["$'0", "$'00","$'000", "$'0000", "$'00000", "$'000000", "$'0000000", "$’000"]
# # Excluded '-' as rowName might possibly have '-' in its name
# specialCharacters = ['`', '~', '!', '@', '#', '$', '%', '^', '&', '*', '(',')', '+', '[', ']', '{', '}', '\\', ':', ';', "'", '"', '|', ',', '<', '.', '>', '/', '?']

# # Iterating all the possible keyWords in usrKeyword
# for keyWord in allRowNames:
#     print("Currently checking for keyWord: '{}'".format(keyWord))
#     # Iterating all pages of PDF to find keyWord
#     for x in range(reader.numPages):
#         pageData = pdf.pages[x]
#         text = pageData.extract_text().lower()

#         # Variables to keep track how to determine left values are the new one or the old one
#         # KIV: Maybe can delete sameMonth & sameYear variables
#     #     sameMonth = 1     # If sameMonth = 1, means need to compare by years for the time period
#     #     sameYear = 1     # If sameYear = 1, means need to compare by months for the time period
#         rightNew = 0     # rightNew = 1 means right value is the NEW one, rightNew = -1 means right value is the OLD one
#         months = []     # months will contain the months of that particular page where keyWord is found
#         years = []     # years will contain the heading of the years of that particular page where keyWord is found, [-1] is the oldYear, [-2] is the newYear

#         # Checking if the keyword is found in a particular page
#         for row in text.split('\n'):
#             if row.startswith(keyWord):
#                 found = 1

#                 # To get the full row name that starts with keyWord
#                 rowName = ""
#                 for i in row:
#                     if (i.isdigit() or i in specialCharacters):
#                         break
#                     else:
#                         rowName += i
#                 rowName = rowName.strip()

#                 # Since the values of a financial statement is always the last few values
#                 # Following example is assuming oldVal is the most right value, and the newVal is the one left of it
#                 # Possible like page 9 of sample1.pdf, where there are 4 values instead

#                 # Need to get the heading as well to know which values belongs to which year / month
#                 # Using a for loop and work backwards into the pdf until we find a heading (rightNew != 0)

#                 for diffPages in range(x, -1, -1):
#                     textHeading = pdf.pages[diffPages].extract_text().lower()

#                     # Limit the search for headings in the first 100 words
#                     for word in textHeading.split()[:100]:
                        
#                         # Trying to get the months
#                         if word in possibleMonths: #and word not in months:
#                             months.append(word)

#                         # To determine which month is the earlier one, assuming there are only 2 months value
#                         if (len(months) >= 2):

#                             # Case 1, when the most right values are the OLD values
#                             if (possibleMonths.index(months[-1]) > possibleMonths.index(months[-2])):
#                                 oldMonth = months[-1].capitalize()
#                                 newMonth = months[-2].capitalize()
#                                 sameMonth = 0
#                                 rightNew = -1

#                             # Case 2, when the most right values are the NEW values
#                             elif (possibleMonths.index(months[-1]) < possibleMonths.index(months[-2])):
#                                 oldMonth = months[-2].capitalize()
#                                 newMonth = months[-1].capitalize()
#                                 sameMonth = 0
#                                 rightNew = 1

#                             # Case 3, when the months are the same, need to compare the years
#                             else:
#                                 oldMonth = newMonth = months[-1].capitalize()
#                                 sameMonth = 1
#                                 rightNew = 0

#                         # If only one month value found in heading
#                         elif (len(months) == 1):
#                             oldMonth = newMonth = months[-1].capitalize()
#                             sameMonth = 1
#                             rightNew = 0

#                         # If only no month values are found in heading
#                         elif (len(months) == 0):
#                             oldMonth = newMonth = ""

#                         # Trying to get the years
#                         try:
#                             if int(word) in possibleYears: #and int(word) not in years:
#                                 years.append(int(word))
#                         except (ValueError):
#                             continue

#                         # To get the currency / units
#                         if word in possibleUnits:
#                             print("TRIGGERED!!!!")
#                             unitMultiplyString = "1" + word.replace("'", '')
#                             unitMultiplyString = unitMultiplyString.replace("’", '')
#                             unitMultiply = int(unitMultiplyString.replace('$',''))
#                             print("unitMultiply = {}".format(unitMultiply))
                        
#                     # Comparing the years
#                     if (len(years) >= 2):

#                         # Case 1: right values are the NEW values
#                         if (years[-1] > years[-2]):
#                             newYear = years[-1]
#                             oldYear = years[-2]
#                             rightNew = 1
#                             sameYear = 0

#                         # Case 2: right values are the OLD values
#                         elif (years[-1] < years[-2]):
#                             oldYear = years[-1]
#                             newYear = years[-2]
#                             rightNew = -1
#                             sameYear = 0

#                         # Case 3: both years are the same, need to compare the months
#                         else:
#                             oldYear = newYear = years[-1]
#                             sameYear = 1

#                     # If only one month value found in heading
#                     elif (len(years) == 1):
#                         oldYear = newYear = years[-1]
#                         sameYear = 1

#                     # If only no month values are found in heading
#                     elif (len(years) == 0):
#                         oldYear = newYear = ""         

#                     # To check whether heading has been found, if found, break, else, continue finding backwards
#                     if (rightNew != 0):
#                         break

#                 # Once we know which value is the NEW one, either right or left, based on the variable rightNew
#                 # Checking whether that particular row has any valid values to gather
#                 # (by checking whether is there any digits in the string)

#                 valid1 = 0     # If valid = 1 by the end of the loop means at least 1 digit in the string, thus valid
#                 valid2 = 0
                
#                 try:
#                     for i in row.split()[-1]:
#                         if i.isdigit():
#                             valid1 = 1
#                     for i in row.split()[-2]:
#                         if i.isdigit():
#                             valid2 = 1

#                     # If not valid, continue to next row to check
#                     if (valid1 == 0 or valid2 == 0):
#                         continue
                
#                 except:
#                     continue
                
#                 # rightNew == 1 means right value is the NEW one
#                 if (rightNew == 1):
#                     newVal = becomeNumber(row.split()[-1])
#                     oldVal = becomeNumber(row.split()[-2])

#                     if (unitMultiply):
#                         oldVal *= unitMultiply
#                         newVal *= unitMultiply
                        
#                     # If either value returns 0 from the function, means invalid
#                     if (oldVal == 0 or newVal == 0):
#                         continue
#                     else:
#                         change = calculateChange(oldVal, newVal)

#                 elif (rightNew == -1):
#                     oldVal = becomeNumber(row.split()[-1])
#                     newVal = becomeNumber(row.split()[-2])
                    
#                     if (unitMultiply):
#                         oldVal *= unitMultiply
#                         newVal *= unitMultiply
                        
#                     # If either value returns 0 from the function, means invalid
#                     if (oldVal == 0 or newVal == 0):
#                         continue
#                     else:
#                         change = calculateChange(oldVal, newVal)

#                 changeVal = newVal - oldVal

#                 # For error checking
#     #             print("months =")
#     #             print(months)
#     #             print("years =")
#     #             print(years)
#     #             print("found = {}, sameMonth = {}, sameYear = {}, rightNew = {}, oldMonth = {}, oldYear = {}, newMonth = {}, newYear = {}".format(found, sameMonth, sameYear, rightNew, oldMonth, oldYear, newMonth, newYear))
#     #             print()

#                 # Printing out the drafting respectively based on the different cases
#                 # [] means need to fill in

#                 try:
#                     print("From page {}:".format(x + 1))

#                     # If only years, but no months are detected in headings
#                     if (newYear and not newMonth):
#                         if (change < 0):
#                             print("Our {} expenses decreased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newYear, oldVal , oldYear))

#                         elif (change > 0):
#                             print("Our {} expenses increased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newYear, oldVal, oldYear))

#                         else:
#                             print("Our {} expenses stayed the same to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, newVal, newYear, oldVal, oldYear))
#                         print()

#                     # If only months, but no years are detected in headings
#                     if (newMonth and not newYear):
#                         if (change < 0):
#                             print("Our {} expenses decreased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newMonth, oldVal, oldMonth))

#                         elif (change > 0):
#                             print("Our {} expenses increased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newMonth, oldVal, oldMonth))

#                         else:
#                             print("Our {} expenses stayed the same to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, newVal, newMonth, oldVal, oldMonth))
#                         print()

#                     # If both months and years are detected in headings
#                     elif (newYear and newMonth):
#                         if (change < 0):
#                             print("Our {} expenses decreased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{} {}], from S$[{:.2f}] in the [{} {}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newMonth, newYear, oldVal, oldMonth, oldYear))

#                         elif (change > 0):
#                             print("Our {} expenses increased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{} {}], from S$[{:.2f}] in the [{} {}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newMonth, newYear, oldVal, oldMonth, oldYear))

#                         else:
#                             print("Our {} expenses stayed the same to S$[{:.2f}] in the [{} {}], from S$[{:.2f}] in the [{} {}], as a result of [company to provide reason].".format(rowName, newVal, newMonth, newYear, oldVal, oldMonth, oldYear))
#                         print()

#                 except:
#                     continue


#     if (found == 0):
#         print("Please double check the keyword to look for and try again")
#         print(quit)

#     else:
#         print("You have reach the end of this program!")
#         print()

# %%
found = 0     # If found = 1, means found the keyWord in PDF, if found = 0, means cannot find keyWord in PDF, need key in a new keyWord again
unitMultiply = 0
possibleYears = range(1900, date.today().year + 1)
# The months are  in small letters so it's not caps-sensitive
possibleMonths = ["december", "november", "october", "september", "august", "july", "june", "may", "april", "march", "february", "january"]
possibleUnits = ["$'0", "$'00","$'000", "$'0000", "$'00000", "$'000000", "$'0000000", "$’000", "’000"]
# Excluded '-' as rowName might possibly have '-' in its name
specialCharacters = ['`', '~', '!', '@', '#', '$', '%', '^', '&', '*', '(',')', '+', '[', ']', '{', '}', '\\', ':', ';', "'", '"', '|', ',', '<', '.', '>', '/', '?']

# Iterating all the possible keyWords in usrKeyword
for keyWord in usrKeyword:
    print("Currently checking for keyWord: '{}'".format(keyWord))
    # Iterating all pages of PDF to find keyWord
    for x in range(reader.numPages):
        pageData = pdf.pages[x]
        text = pageData.extract_text().lower()

        # Variables to keep track how to determine left values are the new one or the old one
        # KIV: Maybe can delete sameMonth & sameYear variables
    #     sameMonth = 1     # If sameMonth = 1, means need to compare by years for the time period
    #     sameYear = 1     # If sameYear = 1, means need to compare by months for the time period
        rightNew = 0     # rightNew = 1 means right value is the NEW one, rightNew = -1 means right value is the OLD one
        months = []     # months will contain the months of that particular page where keyWord is found
        years = []     # years will contain the heading of the years of that particular page where keyWord is found, [-1] is the oldYear, [-2] is the newYear

        # Checking if the keyword is found in a particular page
        for row in text.split('\n'):
            if row.startswith(keyWord):
                found = 1

                # To get the full row name that starts with keyWord
                rowName = ""
                for i in row:
                    if (i.isdigit() or i in specialCharacters):
                        break
                    else:
                        rowName += i
                rowName = rowName.strip()

                # Since the values of a financial statement is always the last few values
                # Following example is assuming oldVal is the most right value, and the newVal is the one left of it
                # Possible like page 9 of sample1.pdf, where there are 4 values instead

                # Need to get the heading as well to know which values belongs to which year / month
                # Using a for loop and work backwards into the pdf until we find a heading (rightNew != 0)

                for diffPages in range(x, -1, -1):
                    textHeading = pdf.pages[diffPages].extract_text().lower()

                    # Limit the search for headings in the first 100 words
                    for word in textHeading.split()[:100]:
                        
                        # Trying to get the months
                        if word in possibleMonths: #and word not in months:
                            months.append(word)

                        # To determine which month is the earlier one, assuming there are only 2 months value
                        if (len(months) >= 2):

                            # Case 1, when the most right values are the OLD values
                            if (possibleMonths.index(months[-1]) > possibleMonths.index(months[-2])):
                                oldMonth = months[-1].capitalize()
                                newMonth = months[-2].capitalize()
                                sameMonth = 0
                                rightNew = -1

                            # Case 2, when the most right values are the NEW values
                            elif (possibleMonths.index(months[-1]) < possibleMonths.index(months[-2])):
                                oldMonth = months[-2].capitalize()
                                newMonth = months[-1].capitalize()
                                sameMonth = 0
                                rightNew = 1

                            # Case 3, when the months are the same, need to compare the years
                            else:
                                oldMonth = newMonth = months[-1].capitalize()
                                sameMonth = 1
                                rightNew = 0

                        # If only one month value found in heading
                        elif (len(months) == 1):
                            oldMonth = newMonth = months[-1].capitalize()
                            sameMonth = 1
                            rightNew = 0

                        # If only no month values are found in heading
                        elif (len(months) == 0):
                            oldMonth = newMonth = ""

                        # Trying to get the years
                        try:
                            if int(word) in possibleYears: #and int(word) not in years:
                                years.append(int(word))
                        except (ValueError):
                            continue

                        # To get the currency / units
                        if word in possibleUnits:
                            print("TRIGGERED!!!!")
                            unitMultiplyString = "1" + word.replace("'", '')
                            unitMultiplyString = unitMultiplyString.replace("’", '')
                            unitMultiply = int(unitMultiplyString.replace('$',''))
                            print("unitMultiply = {}".format(unitMultiply))
                        
                    # Comparing the years
                    if (len(years) >= 2):

                        # Case 1: right values are the NEW values
                        if (years[-1] > years[-2]):
                            newYear = years[-1]
                            oldYear = years[-2]
                            rightNew = 1
                            sameYear = 0

                        # Case 2: right values are the OLD values
                        elif (years[-1] < years[-2]):
                            oldYear = years[-1]
                            newYear = years[-2]
                            rightNew = -1
                            sameYear = 0

                        # Case 3: both years are the same, need to compare the months
                        else:
                            oldYear = newYear = years[-1]
                            sameYear = 1

                    # If only one month value found in heading
                    elif (len(years) == 1):
                        oldYear = newYear = years[-1]
                        sameYear = 1

                    # If only no month values are found in heading
                    elif (len(years) == 0):
                        oldYear = newYear = ""         

                    # To check whether heading has been found, if found, break, else, continue finding backwards
                    if (rightNew != 0):
                        break

                # Once we know which value is the NEW one, either right or left, based on the variable rightNew
                # Checking whether that particular row has any valid values to gather
                # (by checking whether is there any digits in the string)

                valid1 = 0     # If valid = 1 by the end of the loop means at least 1 digit in the string, thus valid
                valid2 = 0
                
                try:
                    for i in row.split()[-1]:
                        if i.isdigit():
                            valid1 = 1
                    for i in row.split()[-2]:
                        if i.isdigit():
                            valid2 = 1

                    # If not valid, continue to next row to check
                    if (valid1 == 0 or valid2 == 0):
                        continue
                
                except:
                    continue
                
                # rightNew == 1 means right value is the NEW one
                if (rightNew == 1):
                    newVal = becomeNumber(row.split()[-1])
                    oldVal = becomeNumber(row.split()[-2])

                    if (unitMultiply):
                        oldVal *= unitMultiply
                        newVal *= unitMultiply
                        
                    # If either value returns 0 from the function, means invalid
                    if (oldVal == 0 or newVal == 0):
                        continue
                    else:
                        change = calculateChange(oldVal, newVal)

                elif (rightNew == -1):
                    oldVal = becomeNumber(row.split()[-1])
                    newVal = becomeNumber(row.split()[-2])
                    
                    if (unitMultiply):
                        oldVal *= unitMultiply
                        newVal *= unitMultiply
                        
                    # If either value returns 0 from the function, means invalid
                    if (oldVal == 0 or newVal == 0):
                        continue
                    else:
                        change = calculateChange(oldVal, newVal)

                changeVal = newVal - oldVal

                # For error checking
    #             print("months =")
    #             print(months)
    #             print("years =")
    #             print(years)
    #             print("found = {}, sameMonth = {}, sameYear = {}, rightNew = {}, oldMonth = {}, oldYear = {}, newMonth = {}, newYear = {}".format(found, sameMonth, sameYear, rightNew, oldMonth, oldYear, newMonth, newYear))
    #             print()

                # Printing out the drafting respectively based on the different cases
                # [] means need to fill in

                try:
                    print("From page {}:".format(x + 1))

                    # If only years, but no months are detected in headings
                    if (newYear and not newMonth):
                        if (change < 0):
                            print("Our {} expenses decreased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newYear, oldVal , oldYear))

                        elif (change > 0):
                            print("Our {} expenses increased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newYear, oldVal, oldYear))

                        else:
                            print("Our {} expenses stayed the same to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, newVal, newYear, oldVal, oldYear))
                        print()

                    # If only months, but no years are detected in headings
                    if (newMonth and not newYear):
                        if (change < 0):
                            print("Our {} expenses decreased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newMonth, oldVal, oldMonth))

                        elif (change > 0):
                            print("Our {} expenses increased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newMonth, oldVal, oldMonth))

                        else:
                            print("Our {} expenses stayed the same to S$[{:.2f}] in the [{}], from S$[{:.2f}] in the [{}], as a result of [company to provide reason].".format(rowName, newVal, newMonth, oldVal, oldMonth))
                        print()

                    # If both months and years are detected in headings
                    elif (newYear and newMonth):
                        if (change < 0):
                            print("Our {} expenses decreased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{} {}], from S$[{:.2f}] in the [{} {}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newMonth, newYear, oldVal, oldMonth, oldYear))

                        elif (change > 0):
                            print("Our {} expenses increased by S${:.2f} ({:.2f})% to S$[{:.2f}] in the [{} {}], from S$[{:.2f}] in the [{} {}], as a result of [company to provide reason].".format(rowName, abs(changeVal), abs(change), newVal, newMonth, newYear, oldVal, oldMonth, oldYear))

                        else:
                            print("Our {} expenses stayed the same to S$[{:.2f}] in the [{} {}], from S$[{:.2f}] in the [{} {}], as a result of [company to provide reason].".format(rowName, newVal, newMonth, newYear, oldVal, oldMonth, oldYear))
                        print()

                except:
                    continue


    if (found == 0):
        print("Please double check the keyword to look for and try again")
        print(quit)

    else:
        print("You have reach the end of this program!")
        print()
# Out:
# Currently checking for keyWord: 'assets'
# From page 14:
# Our assets expenses decreased by S$709141.00 (98.55)% to S$[10419.00] in the [December 2020], from S$[719560.00] in the [January 2020], as a result of [company to provide reason].
#
# From page 15:
# Our assets expenses decreased by S$600734.00 (98.55)% to S$[8826.00] in the [December 2020], from S$[609560.00] in the [January 2020], as a result of [company to provide reason].
#
# From page 58:
# Our assetsheld-for-sale expenses decreased by S$760224.00 (99.17)% to S$[6390.00] in the [December 2020], from S$[766614.00] in the [January 2020], as a result of [company to provide reason].
#
# From page 59:
# Our assetsheld-for-sale expenses increased by S$29284.00 (22354.20)% to S$[29415.00] in the [December 2020], from S$[131.00] in the [January 2019], as a result of [company to provide reason].
#
# From page 60:
# Our assetsheld-for-sale - - expenses decreased by S$313.00 (22.03)% to S$[1108.00] in the [December 2020], from S$[1421.00] in the [January 2020], as a result of [company to provide reason].
#
# You have reach the end of this program!

# %%
# Possible to use this to get the currency out
for x in range(reader.numPages):
    pageData = pdf.pages[x]
    text = pageData.extract_text().lower()
    print("From page {}:".format(x + 1))
#     print(text)
#     print()
    try:
        x = re.search(r"[£$€]", text)
        print(x.group())
    except:
        continue
# Out:
# From page 1:
# From page 2:
# From page 3:
# From page 4:
# From page 5:
# From page 6:
# From page 7:
# From page 8:
# From page 9:
# From page 10:
# From page 11:
# From page 12:
# From page 13:
# From page 14:
# From page 15:
# From page 16:
# From page 17:
# From page 18:
# From page 19:
# From page 20:
# From page 21:
# From page 22:
# From page 23:
# From page 24:
# From page 25:
# From page 26:
# From page 27:
# From page 28:
# From page 29:
# From page 30:
# From page 31:
# From page 32:
# From page 33:
# From page 34:
# From page 35:
# From page 36:
# From page 37:
# From page 38:
# From page 39:
# From page 40:
# From page 41:
# From page 42:
# From page 43:
# From page 44:
# From page 45:
# From page 46:
# From page 47:
# From page 48:
# From page 49:
# From page 50:
# From page 51:
# From page 52:
# From page 53:
# From page 54:
# From page 55:
# From page 56:
# From page 57:
# From page 58:
# From page 59:
# From page 60:
# From page 61:
# From page 62:
# From page 63:
# From page 64:
# From page 65:
# From page 66:
# From page 67:
# From page 68:
# From page 69:
# From page 70:
# From page 71:
# From page 72:
# From page 73:
# From page 74:
# From page 75:
# From page 76:
# From page 77:
# From page 78:
# From page 79:
# From page 80:
# From page 81:
# From page 82:
# From page 83:
# From page 84:
# From page 85:
# From page 86:
# From page 87:
# From page 88:
# From page 89:
# From page 90:
# From page 91:
# From page 92:
# From page 93:

# %%
# Trying out OneAI API
for x in range(reader.numPages):
    api_key = "71902c8e-8005-46a1-bcfb-bca80ef5285a"
    pageData = pdf.pages[x]
    text = pageData.extract_text().lower()
    url = "https://api.oneai.com/api/v0/pipeline"
    headers = {
      "api-key": api_key, 
      "content-type": "application/json"
    }
    payload = {
      "input": text,
      "input_type": "article",
      "steps": [
          {
            "skill": "numbers"
          }
        ]
    }
    r = requests.post(url, json=payload, headers=headers)
    data = r.json()

    # To get the currency out
    for i in data['output'][0]['labels']:
        if (i['name'] == "MONEY"):
            print("From page {}, money = {}".format(x + 1, i['value']))
        if (i['name'] == "NUMBER"):
            print("From page {}, number = {}".format(x + 1, i['value']))
        if (i['name'] == "TIME"):
            print("From page {}, time = {}".format(x + 1, i['value']))
# Out:
# From page 1, number = 1.0
# From page 1, number = 5.0
# From page 1, number = 6.0
# From page 1, number = 8.0
# From page 1, number = 9.0
# From page 1, number = 10.0
# From page 1, number = 11.0
# From page 1, number = 14.0
# From page 1, number = 15.0
# From page 1, number = 16.0
# From page 1, number = 17.0
# From page 2, number = one
# From page 2, number = 10.0
# From page 2, number = 7326.0
# From page 2, number = 82.0
# From page 2, number = 2.0
# From page 2, number = 6676.0
# From page 2, number = 1000.0
# From page 2, number = 82.0
# From page 2, number = 2.0
# From page 2, number = 6674.0
# From page 2, number = 2114.0
# From page 2, number = 17.0
# From page 2, number = 2021.0
# From page 2, number = 31.0
# From page 2, number = 2020.0
# From page 3, number = 2.24
# From page 3, number = 3.0
# From page 3, number = 2.0
# From page 4, number = 11.0
# From page 4, number = 2.12
# From page 4, number = 3.0
# From page 4, number = 3.0
# From page 5, number = one
# From page 5, number = 4.0
# From page 6, number = 5.0
# From page 7, money = millions of korean won
# From page 7, money = thousands of us dollars
# From page 7, number = 2.29
# From page 7, number = 3.0
# From page 7, number = 3.0
# From page 7, number = 31.0
# From page 7, number = 31.0
# From page 7, number = 31.0
# From page 7, number = 3.0
# From page 7, number = 4.0
# From page 7, number = 28.0
# From page 7, number = 29,382,578
# From page 7, number = 26,885,999
# From page 7, number = 24,890,848
# From page 7, number = 22,775,922
# From page 7, number = 4.0
# From page 7, number = 28.0
# From page 7, number = 92,441,703
# From page 7, number = 76,252,052
# From page 7, number = 78,310,091
# From page 7, number = 64,595,361
# From page 7, number = 4.0
# From page 7, number = 28.0
# From page 7, number = 2,757,111
# From page 7, number = 3,914,216
# From page 7, number = 2,335,630
# From page 7, number = 3,315,848
# From page 7, number = 4.0
# From page 7, number = 6,
# From page 7, number = 28.0
# From page 7, number = 71,451
# From page 7, number = 1,727,436
# From page 7, number = 60,528
# From page 7, number = 1,463,362
# From page 7, number = 4.0
# From page 7, number = 5.0
# From page 7, number = 7,
# From page 7, number = 28.0
# From page 7, number = 30,965,058
# From page 7, number = 35,131,343
# From page 7, number = 26,231,413
# From page 7, number = 29,760,796
# From page 7, number = 4.0
# From page 7, number = 7.0
# From page 7, number = 28.0
# From page 7, number = 3,604,539
# From page 7, number = 4,179,120
# From page 7, number = 3,053,511
# From page 7, number = 3,540,256
# From page 7, number = 2,266,100
# From page 7, number = 2,406,220
# From page 7, number = 1,919,680
# From page 7, number = 2,038,380
# From page 7, number = 8.0
# From page 7, number = 32,043,145
# From page 7, number = 26,766,464
# From page 7, number = 27,144,693
# From page 7, number = 22,674,661
# From page 7, number = 4.0
# From page 7, number = 28.0
# From page 7, number = 3,754,462
# From page 7, number = 4,122,410
# From page 7, number = 3,180,515
# From page 7, number = 3,492,215
# From page 7, number = 32.0
# From page 7, number = 929,432
# From page 7, number = 787,350
# From page 7, number = 3.0
# From page 7, number = 198,215,579
# From page 7, number = 181,385,260
# From page 7, number = 167,914,259
# From page 7, number = 153,656,801
# From page 7, number = 4.0
# From page 7, number = 6.0
# From page 7, number = 28.0
# From page 7, number = 12,575,216
# From page 7, number = 8,920,712
# From page 7, number = 10,652,836
# From page 7, number = 7,556,998
# From page 7, number = 4.0
# From page 7, number = 6,
# From page 7, number = 28.0
# From page 7, number = 1,202,969
# From page 7, number = 1,049,004
# From page 7, number = 1,019,070
# From page 7, number = 888,642
# From page 7, number = 9.0
# From page 7, number = 8,076,779
# From page 7, number = 7,591,612
# From page 7, number = 6,842,078
# From page 7, number = 6,431,078
# From page 7, number = 10.0
# From page 7, number = 128,952,892
# From page 7, number = 119,825,474
# From page 7, number = 109,239,795
# From page 7, number = 101,507,691
# From page 7, number = 11.0
# From page 7, number = 18,468,502
# From page 7, number = 20,703,504
# From page 7, number = 15,645,212
# From page 7, number = 17,538,548
# From page 7, number = 14.0
# From page 7, number = 1,355,502
# From page 7, number = 589,832
# From page 7, number = 1,148,286
# From page 7, number = 499,664
# From page 7, number = 25.0
# From page 7, number = 4,275,000
# From page 7, number = 4,505,049
# From page 7, number = 3,621,478
# From page 7, number = 3,816,360
# From page 7, number = 4,7,28
# From page 7, number = 5,113,279
# From page 7, number = 7,994,050
# From page 7, number = 4,331,610
# From page 7, number = 6,771,995
# From page 7, number = 3.0
# From page 7, number = 180,020,139
# From page 7, number = 171,179,237
# From page 7, number = 152,500,365
# From page 7, number = 145,010,976
# From page 7, number = 3.0
# From page 7, number = 378,235,718
# From page 7, number = 352,564,497
# From page 7, number = 320,414,624
# From page 7, number = 298,667,777
# From page 7, number = 6.0
# From page 8, money = millions of korean won
# From page 8, money = thousands of us dollars
# From page 8, number = 2.29
# From page 8, number = 3.0
# From page 8, number = 3.0
# From page 8, number = 31.0
# From page 8, number = 31.0
# From page 8, number = 3.0
# From page 8, number = 4.0
# From page 8, number = 28.0
# From page 8, number = 9,739,222
# From page 8, number = 8,718,222
# From page 8, number = 8,250,382
# From page 8, number = 7,385,463
# From page 8, number = 4.0
# From page 8, number = 5.0
# From page 8, number = 12.0
# From page 8, number = 28.0
# From page 8, number = 16,553,429
# From page 8, number = 14,393,468
# From page 8, number = 14,022,898
# From page 8, number = 12,193,131
# From page 8, number = 4.0
# From page 8, number = 28.0
# From page 8, number = 11,899,022
# From page 8, number = 12,002,513
# From page 8, number = 10,080,012
# From page 8, number = 10,167,683
# From page 8, number = 17.0
# From page 8, number = 1,145,423
# From page 8, number = 1,072,062
# From page 8, number = 970,322
# From page 8, number = 908,175
# From page 8, number = 4.0
# From page 8, number = 28.0
# From page 8, number = 974,521
# From page 8, number = 897,355
# From page 8, number = 825,545
# From page 8, number = 760,176
# From page 8, number = 4.0
# From page 8, number = 17.0
# From page 8, number = 28.0
# From page 8, number = 24,330,339
# From page 8, number = 19,359,624
# From page 8, number = 20,610,947
# From page 8, number = 16,400,108
# From page 8, number = 4,430,272
# From page 8, number = 1,387,773
# From page 8, number = 3,753,014
# From page 8, number = 1,175,623
# From page 8, number = 4.0
# From page 8, number = 12.0
# From page 8, number = 13.0
# From page 8, number = 28.0
# From page 8, number = 716,099
# From page 8, number = 846,090
# From page 8, number = 606,629
# From page 8, number = 716.0
# From page 8, number = 748.0
# From page 8, number = 15.0
# From page 8, number = 4,349,563
# From page 8, number = 4,068,627
# From page 8, number = 3,684,643
# From page 8, number = 3.0
# From page 8, number = 446.0
# From page 8, number = 654.0
# From page 8, number = 4.0
# From page 8, number = 17.0
# From page 8, number = 28.0
# From page 8, number = 1,127,719
# From page 8, number = 1,037,030
# From page 8, number = 955,324
# From page 8, number = 878.0
# From page 8, number = 499.0
# From page 8, number = 32.0
# From page 8, number = 338,742
# From page 8, number = 286,958
# From page 8, number = 3.0
# From page 8, number = 75,604,351
# From page 8, number = 63,782,764
# From page 8, number = 64,046,674
# From page 8, number = 54.0
# From page 8, number = 32.0
# From page 8, number = 260.0
# From page 8, number = 4.0
# From page 8, number = 13.0
# From page 8, number = 28.0
# From page 8, number = 948,137
# From page 8, number = 975,298
# From page 8, number = 803,195
# From page 8, number = 826.0
# From page 8, number = 204.0
# From page 8, number = 4.0
# From page 8, number = 12.0
# From page 8, number = 28.0
# From page 8, number = 1,999,716
# From page 8, number = 2,197,181
# From page 8, number = 1,694,018
# From page 8, number = 1,861,297
# From page 8, number = 4.0
# From page 8, number = 28.0
# From page 8, number = 1,682,910
# From page 8, number = 2,184,249
# From page 8, number = 1,425,643
# From page 8, number = 1,850,342
# From page 8, number = 14.0
# From page 8, number = 464,458
# From page 8, number = 470,780
# From page 8, number = 393,456
# From page 8, number = 398,812
# From page 8, number = 25.0
# From page 8, number = 18,810,845
# From page 8, number = 17,053,808
# From page 8, number = 15,935,221
# From page 8, number = 14.0
# From page 8, number = 446.0
# From page 8, number = 783.0
# From page 8, number = 15.0
# From page 8, number = 1,051,428
# From page 8, number = 611,100
# From page 8, number = 890,696
# From page 8, number = 517.0
# From page 8, number = 681.0
# From page 8, number = 4.0
# From page 8, number = 17.0
# From page 8, number = 28.0
# From page 8, number = 1,725,857
# From page 8, number = 2,408,896
# From page 8, number = 1,462,023
# From page 8, number = 2.0
# From page 8, number = 40.0
# From page 8, number = 645.0
# From page 8, number = 3.0
# From page 8, number = 26,683,351
# From page 8, number = 25,901,312
# From page 8, number = 22,604,252
# From page 8, number = 21.0
# From page 8, number = 941.0
# From page 8, number = 764.0
# From page 8, number = 3.0
# From page 8, number = 102,287,702
# From page 8, number = 89,684,076
# From page 8, number = 86,650,926
# From page 8, number = 75.0
# From page 8, number = 974.0
# From page 8, number = 24.0
# From page 8, number = 7.0
# From page 9, money = thousands of us dollars
# From page 9, number = 2.29
# From page 9, number = 3.0
# From page 9, number = 3.0
# From page 9, number = 31.0
# From page 9, number = 31.0
# From page 9, number = 31.0
# From page 9, number = 3.0
# From page 9, number = 18.0
# From page 9, number = 119,467
# From page 9, number = 119,467
# From page 9, number = 101,204
# From page 9, number = 101,204
# From page 9, number = 18.0
# From page 9, number = 778,047
# From page 9, number = 778,047
# From page 9, number = 659,107
# From page 9, number = 659,107
# From page 9, number = 4,403,893
# From page 9, number = 4,403,893
# From page 9, number = 3,730,668
# From page 9, number = 3,730,668
# From page 9, number = 19.0
# From page 9, number = 271,068,211
# From page 9, number = 254,582,894
# From page 9, number = 229,629,870
# From page 9, number = 215,664,672
# From page 9, number = 20.0
# From page 9, number = 8,687,155
# From page 9, number = 4,968,829
# From page 9, number = 7,359,145
# From page 9, number = 4,209,241
# From page 9, number = 32.0
# From page 9, number = 12,132
# From page 9, number = 10,277
# From page 9, number = 3.0
# From page 9, number = 3.0
# From page 9, number = 267,670,331
# From page 9, number = 254,915,472
# From page 9, number = 226,751,427
# From page 9, number = 215,946,410
# From page 9, number = 31.0
# From page 9, number = 8,277,685
# From page 9, number = 7,964,949
# From page 9, number = 7,012,271
# From page 9, number = 6,747,343
# From page 9, number = 275,948,016
# From page 9, number = 262,880,421
# From page 9, number = 233,763,698
# From page 9, number = 222,693,753
# From page 9, number = 3.0
# From page 9, number = 378,235,718
# From page 9, number = 352,564,497
# From page 9, number = 320,414,624
# From page 9, number = 298,667,777
# From page 9, number = 8.0
# From page 10, money = thousands of us dollars
# From page 10, number = note2.29
# From page 10, number = 3.0
# From page 10, number = 3.0
# From page 10, number = 3.0
# From page 10, number = 29.0
# From page 10, number = 236,806,988
# From page 10, number = 230,400,881
# From page 10, number = 200,606,179
# From page 10, number = 195,179,376
# From page 10, number = 21.0
# From page 10, number = 144,488,296
# From page 10, number = 147,239,549
# From page 10, number = 122,400,294
# From page 10, number = 124,730,961
# From page 10, number = 92,318,692
# From page 10, number = 83,161,332
# From page 10, number = 78,205,885
# From page 10, number = 70,448,415
# From page 10, number = 21.0
# From page 10, number = 22.0
# From page 10, number = 56,324,816
# From page 10, number = 55,392,823
# From page 10, number = 47,714,412
# From page 10, number = 46,924,893
# From page 10, number = 29.0
# From page 10, number = 35,993,876
# From page 10, number = 27,768,509
# From page 10, number = 30,491,473
# From page 10, number = 23,523,522
# From page 10, number = 23.0
# From page 10, number = 1,384,068
# From page 10, number = 1,778,666
# From page 10, number = 1,172,485
# From page 10, number = 1,506,760
# From page 10, number = 23.0
# From page 10, number = 2,488,902
# From page 10, number = 1,414,707
# From page 10, number = 2,108,422
# From page 10, number = 1,198,440
# From page 10, number = 9.0
# From page 10, number = 506,530
# From page 10, number = 412,960
# From page 10, number = 429,096
# From page 10, number = 349,831
# From page 10, number = 24.0
# From page 10, number = 12,267,600
# From page 10, number = 10,161,632
# From page 10, number = 10,392,246
# From page 10, number = 8,608,218
# From page 10, number = 24.0
# From page 10, number = 11,318,055
# From page 10, number = 8,274,871
# From page 10, number = 9,587,858
# From page 10, number = 7,009,887
# From page 10, number = 36,345,117
# From page 10, number = 30,432,189
# From page 10, number = 30,789,020
# From page 10, number = 25,780,004
# From page 10, number = 25.0
# From page 10, number = 9,937,285
# From page 10, number = 8,693,324
# From page 10, number = 8,418,167
# From page 10, number = 7,364,371
# From page 10, number = 3.0
# From page 10, number = 26,407,832
# From page 10, number = 21,738,865
# From page 10, number = 22,370,853
# From page 10, number = 18,415,633
# From page 10, number = 26,090,846
# From page 10, number = 21,505,054
# From page 10, number = 22,102,325
# From page 10, number = 18,217,565
# From page 10, number = 3.0
# From page 10, number = 316,986
# From page 10, number = 233,811
# From page 10, number = 268,528
# From page 10, number = 198,068
# From page 10, number = 3.0
# From page 10, number = 3.0
# From page 10, number = 3.0
# From page 10, number = 3.0
# From page 10, number = 26.0
# From page 10, number = 3,841
# From page 10, number = 3,166
# From page 10, number = 3.25
# From page 10, number = 2.68
# From page 10, number = 3.0
# From page 10, number = 3.0
# From page 10, number = 3,841
# From page 10, number = 3,166
# From page 10, number = 3.25
# From page 10, number = 2.0
# From page 10, number = 68.0
# From page 10, number = 9.0
# From page 11, money = millions of korean won
# From page 11, money = thousands of us dollars
# From page 11, number = 29.0
# From page 11, number = 3.0
# From page 11, number = 3.0
# From page 11, number = 3.0
# From page 11, number = 26,407,832
# From page 11, number = 21,738,865
# From page 11, number = 22,370,853
# From page 11, number = 18,415,633
# From page 11, number = 6.0
# From page 11, number = 20.0
# From page 11, number = 2,502,733
# From page 11, number = 1,146,599
# From page 11, number = 2,120,139
# From page 11, number = 971,318
# From page 11, number = 9,
# From page 11, number = 20.0
# From page 11, number = 5,591
# From page 11, number = 16,896
# From page 11, number = 4,736
# From page 11, number = 14,313
# From page 11, number = 14,
# From page 11, number = 20.0
# From page 11, number = 719,560
# From page 11, number = 1,180,468
# From page 11, number = 609,560
# From page 11, number = 1,000,009
# From page 11, number = 9,
# From page 11, number = 20.0
# From page 11, number = 48,888
# From page 11, number = 48,649
# From page 11, number = 41,414
# From page 11, number = 41,212
# From page 11, number = 20.0
# From page 11, number = 5,380,375
# From page 11, number = 3,016,499
# From page 11, number = 4,557,874
# From page 11, number = 2,555,365
# From page 11, number = 20.0
# From page 11, number = 33,406
# From page 11, number = 1,811
# From page 11, number = 28,300
# From page 11, number = 1,534
# From page 11, number = 3.0
# From page 11, number = 3,673,905
# From page 11, number = 3,016,194
# From page 11, number = 3,112,273
# From page 11, number = 2,555,107
# From page 11, number = 22,733,927
# From page 11, number = 24,755,059
# From page 11, number = 19,258,580
# From page 11, number = 20,970,740
# From page 11, number = 22,374,398
# From page 11, number = 24,466,985
# From page 11, number = 18,954,012
# From page 11, number = 20,726,704
# From page 11, number = 3.0
# From page 11, number = 359,529
# From page 11, number = 288,074
# From page 11, number = 304,568
# From page 11, number = 244,036
# From page 11, number = 10.0
# From page 12, number = 119,467
# From page 12, number = 778,047
# From page 12, number = 4,403,893
# From page 12, number = 242,698,956
# From page 12, number = 7,931,370
# From page 12, number = 240,068,993
# From page 12, number = 7,684,184
# From page 12, number = 247,753,177
# From page 12, number = 21,505,054
# From page 12, number = 233,811
# From page 12, number = 21,738,865
# From page 12, number = 6.0
# From page 12, number = 20.0
# From page 12, number = 1,265
# From page 12, number = 1,111,264
# From page 12, number = 1,109,999
# From page 12, number = 36,600
# From page 12, number = 1,146,599
# From page 12, number = 9,
# From page 12, number = 20.0
# From page 12, number = 608.0
# From page 12, number = 31,477
# From page 12, number = 30,869
# From page 12, number = 884.0
# From page 12, number = 31,753
# From page 12, number = 20.0
# From page 12, number = 2,966,973
# From page 12, number = 2,966,973
# From page 12, number = 49,526
# From page 12, number = 3,016,499
# From page 12, number = 14.0
# From page 12, number = 20.0
# From page 12, number = 1,147,721
# From page 12, number = 1,147,721
# From page 12, number = 32,747
# From page 12, number = 1,180,468
# From page 12, number = 20.0
# From page 12, number = 1,811
# From page 12, number = 1,811
# From page 12, number = 1,811
# From page 12, number = 2,963,804
# From page 12, number = 24,466,985
# From page 12, number = 288,074
# From page 12, number = 24,755,059
# From page 12, number = 19.0
# From page 12, number = 9,619,243
# From page 12, number = 9,619,243
# From page 12, number = 21,359
# From page 12, number = 9,640,602
# From page 12, number = 85.0
# From page 12, number = 85.0
# From page 12, number = 7,356
# From page 12, number = 7,271
# From page 12, number = 5,730
# From page 12, number = 5,730
# From page 12, number = 1,178
# From page 12, number = 1,178
# From page 12, number = 964.0
# From page 12, number = 214.0
# From page 12, number = 9,619,243
# From page 12, number = 1,263
# From page 12, number = 9,620,506
# From page 12, number = 7,309
# From page 12, number = 9,627,815
# From page 12, number = 119,467
# From page 12, number = 778,047
# From page 12, number = 4,403,893
# From page 12, number = 254,582,894
# From page 12, number = 4,968,829
# From page 12, number = 254,915,472
# From page 12, number = 7,964,949
# From page 12, number = 262,880,421
# From page 12, number = 11.0
# From page 13, money = thousands of us dollars
# From page 13, number = 29.0
# From page 13, number = 101,204
# From page 13, number = 659,107
# From page 13, number = 3,730,668
# From page 13, number = 205,597,438
# From page 13, number = 6,718,897
# From page 13, number = 203,369,520
# From page 13, number = 6,509,499
# From page 13, number = 209,879,019
# From page 13, number = 18,217,565
# From page 13, number = 198,068
# From page 13, number = 18,415,633
# From page 13, number = 6.0
# From page 13, number = 20.0
# From page 13, number = 1,072
# From page 13, number = 941,385
# From page 13, number = 940,313
# From page 13, number = 31,005
# From page 13, number = 971,318
# From page 13, number = 9.0
# From page 13, number = 20.0
# From page 13, number = 515.0
# From page 13, number = 26,665
# From page 13, number = 26,150
# From page 13, number = 749.0
# From page 13, number = 26,899
# From page 13, number = 20.0
# From page 13, number = 2,513,410
# From page 13, number = 2,513,410
# From page 13, number = 41,955
# From page 13, number = 2,555,365
# From page 13, number = 14.0
# From page 13, number = 20.0
# From page 13, number = 972,268
# From page 13, number = 972,268
# From page 13, number = 27,741
# From page 13, number = 1,000,009
# From page 13, number = 20.0
# From page 13, number = 1,534
# From page 13, number = 1,534
# From page 13, number = 1,534
# From page 13, number = 2,510,726
# From page 13, number = 20,726,704
# From page 13, number = 244,036
# From page 13, number = 20,970,740
# From page 13, number = 19.0
# From page 13, number = 8,148,744
# From page 13, number = 8,148,744
# From page 13, number = 18,094
# From page 13, number = 8,166,838
# From page 13, number = 72.0
# From page 13, number = 72.0
# From page 13, number = 6,231
# From page 13, number = 6,159
# From page 13, number = 4,854
# From page 13, number = 4,854
# From page 13, number = 998.0
# From page 13, number = 998.0
# From page 13, number = 817.0
# From page 13, number = 181.0
# From page 13, number = 8,148,744
# From page 13, number = 1,070
# From page 13, number = 8,149,814
# From page 13, number = 6,192
# From page 13, number = 8,156,006
# From page 13, number = 101,204
# From page 13, number = 659,107
# From page 13, number = 3,730,668
# From page 13, number = 215,664,672
# From page 13, number = 4,209,241
# From page 13, number = 215,946,410
# From page 13, number = 6,747,343
# From page 13, number = 222,693,753
# From page 13, number = 12.0
# From page 14, money = millions of korean won
# From page 14, number = 2020.0
# From page 14, number = 119,467
# From page 14, number = 778,047
# From page 14, number = 4,403,893
# From page 14, number = 254,582,894
# From page 14, number = 4,968,829
# From page 14, number = 254,915,472
# From page 14, number = 7,964,949
# From page 14, number = 262,880,421
# From page 14, number = 26,090,846
# From page 14, number = 316,986
# From page 14, number = 26,407,832
# From page 14, number = 6.0
# From page 14, number = 20.0
# From page 14, number = 13,713
# From page 14, number = 2,402,226
# From page 14, number = 2,415,939
# From page 14, number = 86,794
# From page 14, number = 2,502,733
# From page 14, number = 9,
# From page 14, number = 20.0
# From page 14, number = 45,894
# From page 14, number = 45,894
# From page 14, number = 2,597
# From page 14, number = 43,297
# From page 14, number = 20.0
# From page 14, number = 5,343,946
# From page 14, number = 5,343,946
# From page 14, number = 36,429
# From page 14, number = 5,380,375
# From page 14, number = 14.0
# From page 14, number = 20.0
# From page 14, number = 709,141
# From page 14, number = 709,141
# From page 14, number = 10,419
# From page 14, number = 719,560
# From page 14, number = 20.0
# From page 14, number = 33,406
# From page 14, number = 33,406
# From page 14, number = 33,406
# From page 14, number = 32.0
# From page 14, number = 12,132
# From page 14, number = 12,132
# From page 14, number = 26,104,559
# From page 14, number = 3,718,029
# From page 14, number = 12,132
# From page 14, number = 22,374,398
# From page 14, number = 359,529
# From page 14, number = 22,733,927
# From page 14, number = 19.0
# From page 14, number = 9,619,242
# From page 14, number = 9,619,242
# From page 14, number = 59,028
# From page 14, number = 9,678,270
# From page 14, number = 830.0
# From page 14, number = 830.0
# From page 14, number = 701.0
# From page 14, number = 1,531
# From page 14, number = 17,838
# From page 14, number = 17,838
# From page 14, number = 533.0
# From page 14, number = 533.0
# From page 14, number = 4,902
# From page 14, number = 4,369
# From page 14, number = 3.0
# From page 14, number = 9,619,242
# From page 14, number = 297.0
# From page 14, number = 9,619,539
# From page 14, number = 46,793
# From page 14, number = 9,666,332
# From page 14, number = 3.0
# From page 14, number = 119,467
# From page 14, number = 778,047
# From page 14, number = 4,403,893
# From page 14, number = 271,068,211
# From page 14, number = 8,687,155
# From page 14, number = 12,132
# From page 14, number = 267,670,331
# From page 14, number = 8,277,685
# From page 14, number = 275,948,016
# From page 14, number = 13.0
# From page 15, money = thousands of us dollars
# From page 15, number = 29.0
# From page 15, number = 101,204
# From page 15, number = 659,107
# From page 15, number = 3,730,668
# From page 15, number = 215,664,672
# From page 15, number = 4,209,241
# From page 15, number = 215,946,410
# From page 15, number = 6,747,343
# From page 15, number = 222,693,753
# From page 15, number = 22,102,325
# From page 15, number = 268,528
# From page 15, number = 22,370,853
# From page 15, number = 6,
# From page 15, number = 20.0
# From page 15, number = 11,617
# From page 15, number = 2,034,996
# From page 15, number = 2,046,613
# From page 15, number = 73,526
# From page 15, number = 2,120,139
# From page 15, number = 9.0
# From page 15, number = 20.0
# From page 15, number = 38,878
# From page 15, number = 38,878
# From page 15, number = 2,200
# From page 15, number = 36,678
# From page 15, number = 20.0
# From page 15, number = 4,527,014
# From page 15, number = 4,527,014
# From page 15, number = 30,860
# From page 15, number = 4,557,874
# From page 15, number = 14.0
# From page 15, number = 20.0
# From page 15, number = 600,734
# From page 15, number = 600,734
# From page 15, number = 8,826
# From page 15, number = 609,560
# From page 15, number = 20.0
# From page 15, number = 28,300
# From page 15, number = 28,300
# From page 15, number = 28,300
# From page 15, number = 32.0
# From page 15, number = 10,277
# From page 15, number = 10,277
# From page 15, number = 3,149,653
# From page 15, number = 10,277
# From page 15, number = 18,954,012
# From page 15, number = 304,568
# From page 15, number = 19,258,580
# From page 15, number = 19.0
# From page 15, number = 8,148,744
# From page 15, number = 8,148,744
# From page 15, number = 50,004
# From page 15, number = 8,198,748
# From page 15, number = 703.0
# From page 15, number = 703.0
# From page 15, number = 594.0
# From page 15, number = 1,297
# From page 15, number = 15,111
# From page 15, number = 15,111
# From page 15, number = 452.0
# From page 15, number = 452.0
# From page 15, number = 4,153
# From page 15, number = 3,701
# From page 15, number = 3.0
# From page 15, number = 8,148,744
# From page 15, number = 251.0
# From page 15, number = 8,148,995
# From page 15, number = 39,640
# From page 15, number = 8,188,635
# From page 15, number = 3.0
# From page 15, number = 101,204
# From page 15, number = 659,107
# From page 15, number = 3,730,668
# From page 15, number = 229,629,870
# From page 15, number = 7,359,145
# From page 15, number = 10,277
# From page 15, number = 226,751,427
# From page 15, number = 7,012,271
# From page 15, number = 233,763,698
# From page 15, number = 14.0
# From page 16, money = millions of korean won
# From page 16, money = thousands of us dollars
# From page 16, number = note2.29
# From page 16, number = 3.0
# From page 16, number = 3.0
# From page 16, number = 31.0
# From page 16, number = 3.0
# From page 16, number = 26,407,832
# From page 16, number = 21,738,865
# From page 16, number = 22,370,853
# From page 16, number = 18,415,633
# From page 16, number = 27.0
# From page 16, number = 41,618,554
# From page 16, number = 37,442,682
# From page 16, number = 35,256,304
# From page 16, number = 31,718,800
# From page 16, number = 27.0
# From page 16, number = 122,424
# From page 16, number = 2,545,756
# From page 16, number = 103,708
# From page 16, number = 2,156,585
# From page 16, number = 68,148,810
# From page 16, number = 56,635,791
# From page 16, number = 57,730,865
# From page 16, number = 47,977,848
# From page 16, number = 2,220,209
# From page 16, number = 2,306,401
# From page 16, number = 1,880,804
# From page 16, number = 1,953,820
# From page 16, number = 555,321
# From page 16, number = 579,979
# From page 16, number = 470,429
# From page 16, number = 491,317
# From page 16, number = 243,666
# From page 16, number = 241,801
# From page 16, number = 206,417
# From page 16, number = 204,837
# From page 16, number = 3.0
# From page 16, number = 4,770,355
# From page 16, number = 13,221,099
# From page 16, number = 4,041,108
# From page 16, number = 11,199,983
# From page 16, number = 3.0
# From page 16, number = 65,287,009
# From page 16, number = 45,382,915
# From page 16, number = 55,306,549
# From page 16, number = 38,445,205
# From page 16, number = 20,369,616
# From page 16, number = 2,030,913
# From page 16, number = 17,255,702
# From page 16, number = 1,720,446
# From page 16, number = 184,104
# From page 16, number = 818,089
# From page 16, number = 155,960
# From page 16, number = 693,027
# From page 16, number = 1,704,512
# From page 16, number = 374,982
# From page 16, number = 1,443,942
# From page 16, number = 317,658
# From page 16, number = 12,184,301
# From page 16, number = 4,586,610
# From page 16, number = 10,321,680
# From page 16, number = 3,885,453
# From page 16, number = 8,019,263
# From page 16, number = 12,725,465
# From page 16, number = 6,793,354
# From page 16, number = 10,780,116
# From page 16, number = 1,023,117
# From page 16, number = 694,584
# From page 16, number = 866,713
# From page 16, number = 588,403
# From page 16, number = 825,027
# From page 16, number = 698,905
# From page 16, number = 32,128
# From page 16, number = 1,575
# From page 16, number = 27,217
# From page 16, number = 1,334
# From page 16, number = 245,497
# From page 16, number = 63,773
# From page 16, number = 207,968
# From page 16, number = 54,024
# From page 16, number = 39,746
# From page 16, number = 64,321
# From page 16, number = 33,670
# From page 16, number = 54,488
# From page 16, number = 84,184
# From page 16, number = 135,826
# From page 16, number = 71,315
# From page 16, number = 115,062
# From page 16, number = 12,149
# From page 16, number = 10,292
# From page 16, number = 83,280
# From page 16, number = 12,778
# From page 16, number = 70,549
# From page 16, number = 10,825
# From page 16, number = 376,744
# From page 16, number = 513,265
# From page 16, number = 319,151
# From page 16, number = 434,802
# From page 16, number = 37,592,034
# From page 16, number = 25,367,756
# From page 16, number = 31,845,320
# From page 16, number = 21,489,774
# From page 16, number = 7,027
# From page 16, number = 7,241
# From page 16, number = 5,953
# From page 16, number = 6,134
# From page 16, number = 2,679,779
# From page 16, number = 3,249,914
# From page 16, number = 2,270,120
# From page 16, number = 2,753,098
# From page 16, number = 49,420
# From page 16, number = 1,019,405
# From page 16, number = 41,865
# From page 16, number = 863,568
# From page 16, number = 3.0
# From page 16, number = 57,197
# From page 16, number = 46,048
# From page 16, number = 48,453
# From page 16, number = 39,008
# From page 16, number = 3.0
# From page 16, number = 53,628,591
# From page 16, number = 39,948,171
# From page 16, number = 45,430,360
# From page 16, number = 33,841,273
# From page 16, number = 15.0
# From page 17, money = millions of korean won
# From page 17, money = thousands of us dollars
# From page 17, number = 29.0
# From page 17, number = 3.0
# From page 17, number = 3.0
# From page 17, number = 31.0
# From page 17, number = 3.0
# From page 17, number = 3.0
# From page 17, number = 2020.0
# From page 17, number = 2019.0
# From page 17, number = 27.0
# From page 17, number = 2,191,186
# From page 17, number = 865,792
# From page 17, number = 1,856,218
# From page 17, number = 733,438
# From page 17, number = 27.0
# From page 17, number = 14,495
# From page 17, number = 12,279
# From page 17, number = 27.0
# From page 17, number = 864,947
# From page 17, number = 709,400
# From page 17, number = 732,722
# From page 17, number = 600,954
# From page 17, number = 9,676,760
# From page 17, number = 9,639,202
# From page 17, number = 8,197,469
# From page 17, number = 8,165,652
# From page 17, number = 3.0
# From page 17, number = 8,187
# From page 17, number = 1,700
# From page 17, number = 6,935
# From page 17, number = 1,440
# From page 17, number = 3.0
# From page 17, number = 8,327,839
# From page 17, number = 9,484,510
# From page 17, number = 7,054,759
# From page 17, number = 8,034,608
# From page 17, number = 32.0
# From page 17, number = 139.0
# From page 17, number = 118.0
# From page 17, number = 3.0
# From page 17, number = 833,861
# From page 17, number = 595,260
# From page 17, number = 706,386
# From page 17, number = 504,262
# From page 17, number = 3.0
# From page 17, number = 2,496,579
# From page 17, number = 3,454,506
# From page 17, number = 2,114,926
# From page 17, number = 2,926,414
# From page 17, number = 3.0
# From page 17, number = 26,885,999
# From page 17, number = 30,340,505
# From page 17, number = 22,775,922
# From page 17, number = 25,702,336
# From page 17, number = 3.0
# From page 17, number = 29,382,578
# From page 17, number = 26,885,999
# From page 17, number = 24,890,848
# From page 17, number = 22,775,922
# From page 17, number = 16.0
# From page 18, number = 1.0
# From page 18, number = 1.1
# From page 18, number = four
# From page 18, number = 1110.0
# From page 18, number = 241.0
# From page 18, number = 1.2
# From page 18, number = 1.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 100.0
# From page 18, number = 100.0
# From page 18, number = 100.0
# From page 18, number = 100.0
# From page 18, number = 100.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 100.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 100.0
# From page 18, number = 0.0
# From page 18, number = 17.0
# From page 19, number = 1.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = seven
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 0.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 100.0
# From page 19, number = 99.9
# From page 19, number = 61.4
# From page 19, number = 2016.0
# From page 19, number = 99.0
# From page 19, number = 0.0
# From page 19, number = 18.0
# From page 20, number = 1.0
# From page 20, number = 100.0
# From page 20, number = 0.0
# From page 20, number = 100.0
# From page 20, number = 0.0
# From page 20, number = 100.0
# From page 20, number = 0.0
# From page 20, number = 100.0
# From page 20, number = 0.0
# From page 20, number = 100.0
# From page 20, number = 0.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 0.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 100.0
# From page 20, number = 0.0
# From page 20, number = 19.0
# From page 21, number = 1.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 100.0
# From page 21, number = 0.0
# From page 21, number = 20.0
# From page 22, number = 1.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 0.0
# From page 22, number = 100.0
# From page 22, number = 0.0
# From page 22, number = 91.8
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 100.0
# From page 22, number = 0.0
# From page 22, number = 21.0
# From page 23, number = 1.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 91.2
# From page 23, number = 88.3
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 90.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 95.0
# From page 23, number = 100.0
# From page 23, number = 60.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 100.0
# From page 23, number = 0.0
# From page 23, number = 22.0
# From page 24, number = 1.0
# From page 24, number = 84.8
# From page 24, number = 50.0
# From page 24, number = 70.0
# From page 24, number = 0.0
# From page 24, number = 91.5
# From page 24, number = 99.3
# From page 24, number = 100.0
# From page 24, number = 100.0
# From page 24, number = 100.0
# From page 24, number = 68.5
# From page 24, number = 99.9
# From page 24, number = 52.5
# From page 24, number = 100.0
# From page 24, number = 100.0
# From page 24, number = 21.0
# From page 24, number = 99.0
# From page 24, number = 22.0
# From page 24, number = 99.0
# From page 24, number = #26
# From page 24, number = 99.0
# From page 24, number = #27
# From page 24, number = 99.0
# From page 24, number = #28
# From page 24, number = 99.0
# From page 24, number = #29
# From page 24, number = 99.0
# From page 24, number = #32
# From page 24, number = 99.0
# From page 24, number = #33
# From page 24, number = 99.0
# From page 24, number = #37
# From page 24, number = 99.0
# From page 24, number = #40
# From page 24, number = 99.0
# From page 24, number = #42
# From page 24, number = 99.0
# From page 24, number = #43
# From page 24, number = 99.0
# From page 24, number = #45
# From page 24, number = 99.0
# From page 24, number = 48.0
# From page 24, number = 99.0
# From page 24, number = 0.0
# From page 24, number = 66.0
# From page 24, number = 7.0
# From page 24, number = 62.0
# From page 24, number = 5.0
# From page 24, number = 23.0
# From page 25, number = 1.0
# From page 25, number = 1.0
# From page 25, number = 50,039,755
# From page 25, number = 7,612,332
# From page 25, number = 27,149,102
# From page 25, number = 1,798,100
# From page 25, number = 36,765,070
# From page 25, number = 15,828,083
# From page 25, number = 35,237,365
# From page 25, number = 1,623,555
# From page 25, number = 15,500,024
# From page 25, number = 2,574,442
# From page 25, number = 28,284,397
# From page 25, number = 2,066,842
# From page 25, number = 15,438,819
# From page 25, number = 12,358,881
# From page 25, number = 2,475,454
# From page 25, number = 127,051
# From page 25, number = 14,702,005
# From page 25, number = 5,776,884
# From page 25, number = 9,161,142
# From page 25, number = 735,426
# From page 25, number = 14,348,735
# From page 25, number = 3,511,003
# From page 25, number = 5,321,312
# From page 25, number = 1,100,619
# From page 25, number = 12,623,956
# From page 25, number = 1,805,326
# From page 25, number = 19,952,957
# From page 25, number = 1,408,088
# From page 25, number = 11,495,430
# From page 25, number = 7,641,709
# From page 25, number = 16.0
# From page 25, number = 150.0
# From page 25, number = 9,669,349
# From page 25, number = 4,427,701
# From page 25, number = 23,562,962
# From page 25, number = 182,290
# From page 25, number = 9,552,755
# From page 25, number = 523,402
# From page 25, number = 1,634,692
# From page 25, number = 968,504
# From page 25, number = 7,678,989
# From page 25, number = 5,010,041
# From page 25, number = 25,829,119
# From page 25, number = 271,691
# From page 25, number = 7,400,563
# From page 25, number = 4,354,887
# From page 25, number = 19,209,100
# From page 25, number = 559,006
# From page 25, number = 6,912,610
# From page 25, number = 538,288
# From page 25, number = 3,913,100
# From page 25, number = 922,007
# From page 25, number = 6,280,131
# From page 25, number = 1,556,057
# From page 25, number = 6,390,696
# From page 25, number = 819.0
# From page 25, number = 561.0
# From page 25, number = 6,250,492
# From page 25, number = 2,523,027
# From page 25, number = 10,943,343
# From page 25, number = 611.0
# From page 25, number = 571.0
# From page 25, number = 2,920,299
# From page 25, number = 451,055
# From page 25, number = 3,744,080
# From page 25, number = 160,264
# From page 25, number = 2,767,563
# From page 25, number = 1,886,447
# From page 25, number = 4,987,522
# From page 25, number = 133,016
# From page 25, number = 2,687,535
# From page 25, number = 2,626,979
# From page 25, number = 6,306,675
# From page 25, number = 605.0
# From page 25, number = 2,609,150
# From page 25, number = 1,026,901
# From page 25, number = 6,273,162
# From page 25, number = 419,313
# From page 25, number = 2,230,457
# From page 25, number = 504,952
# From page 25, number = 3,665,360
# From page 25, number = 148,056
# From page 25, number = 2,145,488
# From page 25, number = 736,480
# From page 25, number = 2,324,308
# From page 25, number = 58,579
# From page 25, number = 1,767,663
# From page 25, number = 300,080
# From page 25, number = 2,947,506
# From page 25, number = 110,194
# From page 25, number = 1,700,033
# From page 25, number = 1,550,350
# From page 25, number = 13,444,960
# From page 25, number = 20,623
# From page 25, number = 1,688,580
# From page 25, number = 1,207,359
# From page 25, number = 3,464,937
# From page 25, number = 61,596
# From page 25, number = 1,668,902
# From page 25, number = 1,381,443
# From page 25, number = 3,317,644
# From page 25, number = 7,684
# From page 25, number = 24.0
# From page 26, number = 2.0
# From page 26, number = 46,543,974
# From page 26, number = 6,421,516
# From page 26, number = 27,088,475
# From page 26, number = 407,791
# From page 26, number = 34,704,039
# From page 26, number = 13,992,397
# From page 26, number = 33,859,423
# From page 26, number = 1,127,719
# From page 26, number = 15,609,084
# From page 26, number = 5,791,272
# From page 26, number = 10,075,626
# From page 26, number = 104,459
# From page 26, number = 14,637,222
# From page 26, number = 11,701,871
# From page 26, number = 3,098,948
# From page 26, number = 581,115
# From page 26, number = 13,847,934
# From page 26, number = 2,075,180
# From page 26, number = 32,831,993
# From page 26, number = 2,305,089
# From page 26, number = 12,370,070
# From page 26, number = 2,678,742
# From page 26, number = 5,445,396
# From page 26, number = 537,037
# From page 26, number = 12,367,857
# From page 26, number = 1,418,876
# From page 26, number = 22,350,791
# From page 26, number = 1,757,684
# From page 26, number = 10,682,847
# From page 26, number = 7,662,042
# From page 26, number = 21,915
# From page 26, number = 9,194,190
# From page 26, number = 3,795,273
# From page 26, number = 16,473,214
# From page 26, number = 211,312
# From page 26, number = 9,137,262
# From page 26, number = 579,618
# From page 26, number = 1,572,146
# From page 26, number = 1,265,359
# From page 26, number = 7,267,124
# From page 26, number = 4,587,477
# From page 26, number = 16,613,123
# From page 26, number = 601,469
# From page 26, number = 7,058,719
# From page 26, number = 1,594,907
# From page 26, number = 7,252,673
# From page 26, number = 887,298
# From page 26, number = 7,042,872
# From page 26, number = 3,588,241
# From page 26, number = 12,902,906
# From page 26, number = 448,678
# From page 26, number = 6,437,865
# From page 26, number = 556,765
# From page 26, number = 3,897,162
# From page 26, number = 571,391
# From page 26, number = 5,880,616
# From page 26, number = 4,446,885
# From page 26, number = 26,067,175
# From page 26, number = 265,801
# From page 26, number = 2,912,731
# From page 26, number = 450,833
# From page 26, number = 3,921,248
# From page 26, number = 144,087
# From page 26, number = 2,644,358
# From page 26, number = 1,877,903
# From page 26, number = 4,730,414
# From page 26, number = 104,741
# From page 26, number = 2,305,587
# From page 26, number = 1,035,533
# From page 26, number = 4,934,278
# From page 26, number = 373,325
# From page 26, number = 2,258,269
# From page 26, number = 2,199,561
# From page 26, number = 5,597,323
# From page 26, number = 4,729
# From page 26, number = 2,109,654
# From page 26, number = 416,160
# From page 26, number = 2,915,812
# From page 26, number = 106,704
# From page 26, number = 2,091,092
# From page 26, number = 1,954,875
# From page 26, number = 4,283,163
# From page 26, number = 53,160
# From page 26, number = 2,027,213
# From page 26, number = 1,891,221
# From page 26, number = 12,540,817
# From page 26, number = 6,531
# From page 26, number = 1,914,864
# From page 26, number = 673,887
# From page 26, number = 2,246,357
# From page 26, number = 39,175
# From page 26, number = 1,808,262
# From page 26, number = 625,541
# From page 26, number = 1,415,505
# From page 26, number = 4,414
# From page 26, number = 1,795,077
# From page 26, number = 444,552
# From page 26, number = 3,995,696
# From page 26, number = 158,122
# From page 26, number = 25.0
# ...
# From page 84, number = 20,966
# From page 84, number = 2,592,428
# From page 84, number = 2,776,440
# From page 84, number = 208,126
# From page 84, number = 208,126
# From page 84, number = 2.0
# From page 84, number = 1,013,245
# From page 84, number = 1,013,245
# From page 84, number = 2,316
# From page 84, number = 2,316
# From page 84, number = 215,211
# From page 84, number = 215,211
# From page 84, number = 3577.0
# From page 84, number = 1.0
# From page 84, number = 3577.0
# From page 84, number = 2.0
# From page 84, number = 1.0
# From page 84, number = 3577.0
# From page 84, number = 3.0
# From page 84, number = 1.0
# From page 84, number = 1.0
# From page 84, number = 2.0
# From page 84, number = 83.0
# From page 85, number = one
# From page 85, number = 3.0
# From page 85, number = 3.0
# From page 85, number = quarter
# From page 85, number = 3577.0
# From page 85, number = 3577.0
# From page 85, number = 3.0
# From page 85, number = 2.0
# From page 85, number = 3.0
# From page 85, number = 3.0
# From page 85, number = 3.0
# From page 85, number = 9,121
# From page 85, number = 22,060
# From page 85, number = 4,775,362
# From page 85, number = 3.0
# From page 85, number = 3.0
# From page 85, number = 2,176
# From page 85, number = 84.0
# From page 86, number = 4.0
# From page 86, number = 3.0
# From page 86, number = 7,407,684
# From page 86, number = 7,165,466
# From page 86, number = 882,331
# From page 86, number = 3,592,512
# From page 86, number = 2,531,276
# From page 86, number = 3,795,486
# From page 86, number = 55,103
# From page 86, number = 53,381
# From page 86, number = 829,764
# From page 86, number = 302,616
# From page 86, number = 84,261
# From page 86, number = 89,195
# From page 86, number = 6,449,139
# From page 86, number = 7,407,684
# From page 86, number = 2,316
# From page 86, number = 14,502
# From page 86, number = 1,130
# From page 86, number = 196.0
# From page 86, number = 11,655
# From page 86, number = 6,736
# From page 86, number = 599.0
# From page 86, number = 9,248
# From page 86, number = 2,316
# From page 86, number = 5.0
# From page 86, number = 3.0
# From page 86, number = more than two
# From page 86, number = 3.0
# From page 86, money = millions of korean won
# From page 86, number = 1659.0
# From page 86, number = 181,764
# From page 86, number = 150,620
# From page 86, number = -1.0
# From page 86, number = 1.0
# From page 86, number = 85.0
# From page 87, number = 29.0
# From page 87, number = 1.0
# From page 87, number = 3.0
# From page 87, number = 3.0
# From page 87, number = 110,116,900
# From page 87, number = 208,211,782
# From page 87, number = 211,477,724
# From page 87, number = 142,840,934
# From page 87, number = 65,824,403
# From page 87, number = 10,298,318
# From page 87, number = 542,059,756
# From page 87, number = 305,252,768
# From page 87, number = 236,806,988
# From page 87, number = 61,943,576
# From page 87, number = 108,624,289
# From page 87, number = 108,441,578
# From page 87, number = 69,983,131
# From page 87, number = 35,238,688
# From page 87, number = 1,114,570
# From page 87, number = 305,252,768
# From page 87, number = 305,252,768
# From page 87, number = 48,173,324
# From page 87, number = 99,587,493
# From page 87, number = 103,036,146
# From page 87, number = 72,857,803
# From page 87, number = 30,585,715
# From page 87, number = 9,183,748
# From page 87, number = 236,806,988
# From page 87, number = 236,806,988
# From page 87, number = 582,929
# From page 87, number = 855,573
# From page 87, number = 24,330,737
# From page 87, number = 18,124,847
# From page 87, number = 6,183,077
# From page 87, number = 264,928
# From page 87, number = 27,115,735
# From page 87, number = 27,115,735
# From page 87, number = 76,270
# From page 87, number = 1,394,396
# From page 87, number = 1,321,305
# From page 87, number = 1,053,892
# From page 87, number = 257,446
# From page 87, number = 233,518
# From page 87, number = 3,219,881
# From page 87, number = 3,219,881
# From page 87, number = 3,561,536
# From page 87, number = 11,472,671
# From page 87, number = 21,120,231
# From page 87, number = 18,804,970
# From page 87, number = 2,236,919
# From page 87, number = 55,518
# From page 87, number = 35,993,876
# From page 87, number = 35,993,876
# From page 87, number = 2.0
# From page 87, number = 3.0
# From page 87, number = 3.0
# From page 87, number = 3.0
# From page 87, number = 100,402,724
# From page 87, number = 223,959,110
# From page 87, number = 193,141,859
# From page 87, number = 123,766,753
# From page 87, number = 66,908,763
# From page 87, number = 11,749,815
# From page 87, number = 531,113,681
# From page 87, number = 300,712,800
# From page 87, number = 230,400,881
# From page 87, number = 55,079,879
# From page 87, number = 116,692,955
# From page 87, number = 97,623,857
# From page 87, number = 58,827,701
# From page 87, number = 35,854,834
# From page 87, number = 1,672,719
# From page 87, number = 300,712,800
# From page 87, number = 300,712,800
# From page 87, number = 45,322,843
# From page 87, number = 107,266,155
# From page 87, number = 95,518,002
# From page 87, number = 64,939,052
# From page 87, number = 31,053,929
# From page 87, number = 10,077,096
# From page 87, number = 230,400,881
# From page 87, number = 230,400,881
# From page 87, number = 554,467
# From page 87, number = 1,215,268
# From page 87, number = 23,584,306
# From page 87, number = 17,017,054
# From page 87, number = 6,533,810
# From page 87, number = 337,609
# From page 87, number = 26,573,816
# From page 87, number = 26,573,816
# From page 87, number = 73,536
# From page 87, number = 1,388,619
# From page 87, number = 1,138,678
# From page 87, number = 836,951
# From page 87, number = 291,721
# From page 87, number = 232,104
# From page 87, number = 3,023,822
# From page 87, number = 3,023,822
# From page 87, number = 2,508,998
# From page 87, number = 9,272,468
# From page 87, number = 15,581,687
# From page 87, number = 14,016,302
# From page 87, number = 1,581,333
# From page 87, number = 322,331
# From page 87, number = 27,768,509
# From page 87, number = 27,768,509
# From page 87, number = 86.0
# From page 88, number = 1.0
# From page 88, number = 37,035,377
# From page 88, number = 78,305,571
# From page 88, number = 45,967,097
# From page 88, number = 37,692,286
# From page 88, number = 37,806,657
# From page 88, number = 236,806,988
# From page 88, number = 110,075,478
# From page 88, number = 9,035,206
# From page 88, number = 6,087,436
# From page 88, number = 8,972,711
# From page 88, number = 13,782,478
# From page 88, number = 531,915
# From page 88, number = 147,421,394
# From page 88, number = 2.0
# From page 88, number = 34,180,362
# From page 88, number = 73,851,914
# From page 88, number = 42,713,958
# From page 88, number = 41,614,112
# From page 88, number = 38,040,535
# From page 88, number = 230,400,881
# From page 88, number = 100,315,093
# From page 88, number = 10,357,696
# From page 88, number = 6,648,962
# From page 88, number = 11,030,300
# From page 88, number = 12,598,701
# From page 88, number = 421,774
# From page 88, number = 140,528,978
# From page 88, number = 87.0
# From page 89, number = 30.0
# From page 89, number = 108,634
# From page 89, number = 77.0
# From page 89, number = 1,752,792
# From page 89, number = 469,270
# From page 89, number = 37,837
# From page 89, number = 1,664,069
# From page 89, number = 73,561
# From page 89, number = 272.0
# From page 89, number = 601,286
# From page 89, number = 91,949
# From page 89, number = 26,996
# From page 89, number = 649,164
# From page 89, number = 1,059,045
# From page 89, number = 30.0
# From page 89, number = 10,556,776
# From page 89, number = 166,842
# From page 89, number = 1,306,073
# From page 89, number = 379.0
# From page 89, number = 15,224,087
# From page 89, number = 728,061
# From page 89, number = 94,736
# From page 89, number = 43,214
# From page 89, number = 328,484
# From page 89, number = 4,057,233
# From page 89, number = 309,819
# From page 89, number = 1,105,252
# From page 89, number = 497,163
# From page 89, number = 404,555
# From page 89, number = 43,214
# From page 89, number = 1,433,736
# From page 89, number = 4,554,396
# From page 89, number = 4,104
# From page 89, number = 70,073
# From page 89, number = 1,946,409
# From page 89, number = 1.0
# From page 89, number = 17,199
# From page 89, number = 436,211
# From page 89, number = 43,336
# From page 89, number = 100,591
# From page 89, number = 422,989
# From page 89, number = 172,023
# From page 89, number = 121,894
# From page 89, number = 929,273
# From page 89, number = 2,161,768
# From page 89, number = 2.0
# From page 89, number = 1024.0
# From page 89, number = 2019.0
# From page 89, number = 85,415
# From page 89, number = 2,018,871
# From page 89, number = 498,722
# From page 89, number = 48,874
# From page 89, number = 2,214,388
# From page 89, number = 16.0
# From page 89, number = 93,634
# From page 89, number = 16,106
# From page 89, number = 626,320
# From page 89, number = 80,886
# From page 89, number = 25,821
# From page 89, number = 813,808
# From page 89, number = 958.0
# From page 89, number = 914,634
# From page 89, number = 2.0
# From page 89, number = 10,482,459
# From page 89, number = 245,683
# From page 89, number = 1,168,378
# From page 89, number = 16,108
# From page 89, number = 16,155,846
# From page 89, number = 826,265
# From page 89, number = 116,272
# From page 89, number = 17,367
# From page 89, number = 383,645
# From page 89, number = 4,208,197
# From page 89, number = 204,758
# From page 89, number = 1,078,775
# From page 89, number = 1,168,865
# From page 89, number = 321,030
# From page 89, number = 17,367
# From page 89, number = 1,462,420
# From page 89, number = 5,377,062
# From page 89, number = 5,675
# From page 89, number = 81,169
# From page 89, number = 2,001,467
# From page 89, number = 1.0
# From page 89, number = 18,270
# From page 89, number = 406,685
# From page 89, number = 29,153
# From page 89, number = 125,320
# From page 89, number = 1,477
# From page 89, number = 365,795
# From page 89, number = 557,852
# From page 89, number = 149,265
# From page 89, number = 1,477
# From page 89, number = 853,649
# From page 89, number = 2,588,472
# From page 89, number = 88.0
# From page 90, number = 2.0
# From page 90, number = 1024.0
# From page 90, number = 31.0
# From page 90, number = 2020.0
# From page 90, number = 36,905
# From page 90, number = 543,388
# From page 90, number = 379.0
# From page 90, number = 120,407
# From page 90, number = 108,561
# From page 90, number = 89,178
# From page 90, number = 195.0
# From page 90, number = 398,836
# From page 90, number = 253,921
# From page 90, number = 1,154,549
# From page 90, number = 399,961
# From page 90, number = 2,306,358
# From page 90, number = 245,138
# From page 90, number = 2,327,126
# From page 90, number = 20,484
# From page 90, number = 172,726
# From page 90, number = 265,622
# From page 90, number = 2,499,852
# From page 90, number = 492.0
# From page 90, number = 538,853
# From page 90, number = 1.0
# From page 90, number = 2,091
# From page 90, number = 45,257
# From page 90, number = 11,344
# From page 90, number = 55,053
# From page 90, number = 13,927
# From page 90, number = 639,163
# From page 90, number = 1024.0
# From page 90, number = 19,723
# From page 90, number = 636,169
# From page 90, number = 2,457
# From page 90, number = 207,339
# From page 90, number = 103,809
# From page 90, number = 135,048
# From page 90, number = 423.0
# From page 90, number = 415,785
# From page 90, number = 177,491
# From page 90, number = 997,632
# From page 90, number = 303,903
# From page 90, number = 2,391,973
# From page 90, number = 230,535
# From page 90, number = 1,215,575
# From page 90, number = 18,884
# From page 90, number = 170,130
# From page 90, number = 249,419
# From page 90, number = 1,385,705
# From page 90, number = 2,734
# From page 90, number = 629,584
# From page 90, number = 1.0
# From page 90, number = 1,464
# From page 90, number = 50,498
# From page 90, number = 12,211
# From page 90, number = 115,072
# From page 90, number = 16,409
# From page 90, number = 795,154
# From page 90, number = 89.0
# From page 91, number = 1024.0
# From page 91, number = 83,280 million
# From page 91, number = 12,822 million
# From page 91, money = w785,000million
# From page 91, number = 659.0
# From page 91, number = 661.0
# From page 91, money = w 125,744 million
# From page 91, number = 1024.0
# From page 91, number = 31.0
# From page 91, number = 2020.0
# From page 91, number = 026 million
# From page 91, money = millions of korean won
# From page 91, number = 13,333
# From page 91, number = 9,821
# From page 91, number = 987.0
# From page 91, number = 1,321
# From page 91, number = 7,287
# From page 91, number = 6,449
# From page 91, number = 90.0
# From page 92, number = 31.0
# From page 92, money = millions of korean won
# From page 92, number = 1.0
# From page 92, number = 7,427,228
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 7,181,049
# From page 92, number = 294,139
# From page 92, number = 212,351
# From page 92, number = 54,121
# From page 92, number = 3,797
# From page 92, number = 56,538
# From page 92, number = 37.0
# From page 92, number = 625.0
# From page 92, number = 31.0
# From page 92, number = 7,723,784
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 7.0
# From page 92, number = 427.0
# From page 92, number = 228.0
# From page 92, number = 31.0
# From page 92, number = 2020.0
# From page 92, number = 1.0
# From page 92, number = 28,354,913
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 23,388,388
# From page 92, number = 26,904,627
# From page 92, number = 30,343,285
# From page 92, number = 7,631,559
# From page 92, number = 5,482,650
# From page 92, number = 841,323
# From page 92, number = 3,687,057
# From page 92, number = 46,786,658
# From page 92, number = 44,561,966
# From page 92, number = 46,282,988
# From page 92, number = 44,021,178
# From page 92, number = 503,670
# From page 92, number = 540,788
# From page 92, number = 2.0
# From page 92, number = 30,474,830
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 3.0
# From page 92, number = 30,957,776
# From page 92, number = 1,874,486
# From page 92, number = 1,139,753
# From page 92, number = 408,022
# From page 92, number = 161,549
# From page 92, number = 2,282,508
# From page 92, number = 1,301,302
# From page 92, number = 2,267,953
# From page 92, number = 1,285,056
# From page 92, number = 14,555
# From page 92, number = 16,246
# From page 92, number = 91.0
# From page 93, number = 3.0
# From page 93, number = 7,800,766
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 3.0
# From page 93, number = 7,606,805
# From page 93, number = 6,933,401
# From page 93, number = 6,108,946
# From page 93, number = 536,883
# From page 93, number = 1,503,785
# From page 93, number = 139.0
# From page 93, number = 27,688
# From page 93, number = 2,435
# From page 93, number = 302,655
# From page 93, number = 3,491
# From page 93, number = 672,880
# From page 93, number = 676,371
# From page 93, number = 975,535
# From page 93, number = 672,880
# From page 93, number = 32.0
# From page 93, number = 139.0
# From page 93, number = 53,157
# From page 93, number = 26,474
# From page 93, number = 766,614
# From page 93, number = 1,421
# From page 93, number = 81,627
# From page 93, number = 929,432
# From page 93, number = 337,032
# From page 93, number = 1,710
# From page 93, number = 338,742
# From page 93, number = 12,132
# From page 93, number = 92.0
